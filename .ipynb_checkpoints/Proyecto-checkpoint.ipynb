# %% [markdown]
# # Análisis Manu Ginobili
#
# ### por Rodrigo Martin Alisón
#
# Este es un breve analisis de las estadisticas de Emanuel Ginobili durante sus años de carrera en la NBA. Buscare encontrar algunas correlaciones entre sus números (minutos y partidos jugados) con su edad, asi como fueron evolucionando sus estadistintas en los rubros individuales. Finalmente intentare obtener la influencia de Emanuel en su equipo (San Antonio Spurs) analizando la cantidad de partidos ganados y perdidos con su presencia o sin la misma.
#
# ## Objetivos
#
# Con el presente análisis buscare responder las siguientes preguntas:
#
# 1. Cual fue el promedio de puntos por partidos y por minutos jugados de Emanuel Ginobili durante su carrera en la NBA? Como se distribuyo durante sus diferentes temporadas?
# 2. Cual fue el promedio de minutos jugados durante su carrera en la NBA? Como se distribuyo durante sus diferentes temporadas?
# 3. Cual fue el porcentaje de partidos de titular que jugo? Fue variando en los distintos años?
# 4. Como evolucionaron sus estadisticas en los distintos rubros durante toda su carrera?
# 5. Como fueron los resultados del equipo con el en cancha o sin su presencia?
#
#
# ## Indice
#
# 1. <a href="#carga">Carga de datos</a>
# 2. <a href="#exploracion">Exploración</a>
# 3. <a href="#limpieza">Limpieza de datos</a>
# 4. <a href="#presentacion">Presentación de los datos</a>
# 5. <a href="#conclusiones">Conclusiones</a>
# 6. <a href="#referencias">Referencias</a>

# %% [markdown]
# ## 1. Carga de Datos <a id="carga"></a>

# %%
#Importamos librerias 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as sty
import seaborn as sns
import numpy as np
import math

# %matplotlib inline

# %%
#Carga y lectura de archivos
path_games_details = "archivos/games_details.csv"
arc_games_details = pd.read_csv(path_games_details)
# Out:
# E:\win10\Alison\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
path_games = "archivos/games.csv"
arc_games = pd.read_csv(path_games)

# %% [markdown]
# ## 2. Exploración <a id="exploracion"></a>

# %% [markdown]
# Comenzamos a analizar la información que trae cada archivo y tener mas conocimiento de los datos con que contamos.

# %%
arc_games_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626111 entries, 0 to 626110
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   GAME_ID            626111 non-null  int64
#  1   TEAM_ID            626111 non-null  int64
#  2   TEAM_ABBREVIATION  626111 non-null  object
#  3   TEAM_CITY          626111 non-null  object
#  4   PLAYER_ID          626111 non-null  int64
#  5   PLAYER_NAME        626111 non-null  object
#  6   NICKNAME           10485 non-null   object
#  7   START_POSITION     239375 non-null  object
#  8   COMMENT            102359 non-null  object
#  9   MIN                523751 non-null  object
#  10  FGM                523751 non-null  float64
#  11  FGA                523751 non-null  float64
#  12  FG_PCT             523751 non-null  float64
#  13  FG3M               523751 non-null  float64
#  14  FG3A               523751 non-null  float64
#  15  FG3_PCT            523751 non-null  float64
#  16  FTM                523751 non-null  float64
#  17  FTA                523751 non-null  float64
#  18  FT_PCT             523751 non-null  float64
#  19  OREB               523751 non-null  float64
#  20  DREB               523751 non-null  float64
#  21  REB                523751 non-null  float64
#  22  AST                523751 non-null  float64
#  23  STL                523751 non-null  float64
#  24  BLK                523751 non-null  float64
#  25  TO                 523751 non-null  float64
#  26  PF                 523751 non-null  float64
#  27  PTS                523751 non-null  float64
#  28  PLUS_MINUS         500090 non-null  float64
# dtypes: float64(19), int64(3), object(7)
# memory usage: 138.5+ MB

# %%
arc_games_details.sample(5)
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 364653  21900154  1610612763               MEM    Memphis     203937
# 600006  21200920  1610612739               CLE  Cleveland     201956
# 323540  21000030  1610612756               PHX    Phoenix     201947
# 547273  21400101  1610612741               CHI    Chicago     202734
# 60999   21900434  1610612752               NYK   New York     203901
#
#           PLAYER_NAME NICKNAME START_POSITION  \
# 364653  Kyle Anderson      NaN            NaN
# 600006    Omri Casspi      NaN            NaN
# 323540     Earl Clark      NaN            NaN
# 547273  E'Twaun Moore      NaN            NaN
# 60999   Elfrid Payton      NaN              G
#
#                                          COMMENT    MIN  ...  OREB  DREB  REB  \
# 364653                                       NaN  17:24  ...   1.0   6.0  7.0
# 600006                        DND - Appendectomy    NaN  ...   NaN   NaN  NaN
# 323540                    DNP - Coach's Decision    NaN  ...   NaN   NaN  NaN
# 547273  DNP - Coach's Decision                      NaN  ...   NaN   NaN  NaN
# 60999                                        NaN  27:10  ...   2.0   3.0  5.0
#
#          AST  STL  BLK   TO   PF  PTS  PLUS_MINUS
# 364653   4.0  3.0  1.0  1.0  3.0  5.0         6.0
# 600006   NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 323540   NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 547273   NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 60999   10.0  4.0  0.0  2.0  2.0  6.0       -21.0
#
# [5 rows x 29 columns]

# %%
arc_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25024 entries, 0 to 25023
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     25024 non-null  object
#  1   GAME_ID           25024 non-null  int64
#  2   GAME_STATUS_TEXT  25024 non-null  object
#  3   HOME_TEAM_ID      25024 non-null  int64
#  4   VISITOR_TEAM_ID   25024 non-null  int64
#  5   SEASON            25024 non-null  int64
#  6   TEAM_ID_home      25024 non-null  int64
#  7   PTS_home          24925 non-null  float64
#  8   FG_PCT_home       24925 non-null  float64
#  9   FT_PCT_home       24925 non-null  float64
#  10  FG3_PCT_home      24925 non-null  float64
#  11  AST_home          24925 non-null  float64
#  12  REB_home          24925 non-null  float64
#  13  TEAM_ID_away      25024 non-null  int64
#  14  PTS_away          24925 non-null  float64
#  15  FG_PCT_away       24925 non-null  float64
#  16  FT_PCT_away       24925 non-null  float64
#  17  FG3_PCT_away      24925 non-null  float64
#  18  AST_away          24925 non-null  float64
#  19  REB_away          24925 non-null  float64
#  20  HOME_TEAM_WINS    25024 non-null  int64
# dtypes: float64(12), int64(7), object(2)
# memory usage: 4.0+ MB

# %%
arc_games.sample(5)
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 4014     2013-04-09  21201159            Final    1610612763       1610612766
# 16924    2004-01-24  20300624            Final    1610612759       1610612740
# 24895    2014-10-31  21400025            Final    1610612758       1610612757
# 721      2021-04-05  22000767            Final    1610612759       1610612739
# 10381    2008-11-19  20800165            Final    1610612760       1610612746
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 4014     2012    1610612763      94.0        0.476        0.650  ...
# 16924    2003    1610612759      96.0        0.493        0.654  ...
# 24895    2014    1610612758     103.0        0.420        0.886  ...
# 721      2020    1610612759     101.0        0.422        0.813  ...
# 10381    2008    1610612760      88.0        0.400        1.000  ...
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 4014       17.0      48.0    1610612766      75.0        0.375        0.722
# 16924      22.0      39.0    1610612740      98.0        0.452        0.833
# 24895      14.0      49.0    1610612757      94.0        0.410        0.895
# 721        22.0      38.0    1610612739     125.0        0.523        0.852
# 10381      16.0      42.0    1610612746     108.0        0.474        0.846
#
#        FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 4014          0.143      13.0      44.0               1
# 16924         0.438      14.0      39.0               0
# 24895         0.346      20.0      38.0               1
# 721           0.353      29.0      47.0               0
# 10381         0.313      24.0      44.0               0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 3. Limpieza de datos <a id="limpieza"></a>

# %%
#Copia a archivos para trabajar en duplicado
arc_games_details_copia = arc_games_details.copy()
arc_games_copia = arc_games.copy()

# %%
#Hacemos el merge entre los archivos que vamos a usar
merge_games_gamesdetails = arc_games_details_copia.merge(arc_games_copia, on = ['GAME_ID'])

# %%
#Analizamos el dataset obtenido
merge_games_gamesdetails
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 0       22100213  1610612764               WAS  Washington     203484
# 1       22100213  1610612764               WAS  Washington    1628398
# 2       22100213  1610612764               WAS  Washington    1629655
# 3       22100213  1610612764               WAS  Washington     203078
# 4       22100213  1610612764               WAS  Washington     203915
# ...          ...         ...               ...         ...        ...
# 627521  11200005  1610612743               DEN      Denver     202706
# 627522  11200005  1610612743               DEN      Denver     202702
# 627523  11200005  1610612743               DEN      Denver     201585
# 627524  11200005  1610612743               DEN      Denver     202389
# 627525  11200005  1610612743               DEN      Denver     201951
#
#                      PLAYER_NAME    NICKNAME START_POSITION COMMENT    MIN  \
# 0       Kentavious Caldwell-Pope  Kentavious              F     NaN  27:41
# 1                     Kyle Kuzma        Kyle              F     NaN  30:28
# 2                 Daniel Gafford      Daniel              C     NaN  24:21
# 3                   Bradley Beal     Bradley              G     NaN  35:07
# 4              Spencer Dinwiddie     Spencer              G     NaN  28:34
# ...                          ...         ...            ...     ...    ...
# 627521           Jordan Hamilton         NaN            NaN     NaN     19
# 627522            Kenneth Faried         NaN            NaN     NaN     23
# 627523              Kosta Koufos         NaN            NaN     NaN     15
# 627524            Timofey Mozgov         NaN            NaN     NaN     19
# 627525                 Ty Lawson         NaN            NaN     NaN     27
#
#         ...  AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  \
# 0       ...      30.0      59.0    1610612764      87.0        0.367
# 1       ...      30.0      59.0    1610612764      87.0        0.367
# 2       ...      30.0      59.0    1610612764      87.0        0.367
# 3       ...      30.0      59.0    1610612764      87.0        0.367
# 4       ...      30.0      59.0    1610612764      87.0        0.367
# ...     ...       ...       ...           ...       ...          ...
# 627521  ...      21.0      40.0    1610612743     106.0        0.532
# 627522  ...      21.0      40.0    1610612743     106.0        0.532
# 627523  ...      21.0      40.0    1610612743     106.0        0.532
# 627524  ...      21.0      40.0    1610612743     106.0        0.532
# 627525  ...      21.0      40.0    1610612743     106.0        0.532
#
#         FT_PCT_away  FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 0             0.813         0.190      23.0      48.0               1
# 1             0.813         0.190      23.0      48.0               1
# 2             0.813         0.190      23.0      48.0               1
# 3             0.813         0.190      23.0      48.0               1
# 4             0.813         0.190      23.0      48.0               1
# ...             ...           ...       ...       ...             ...
# 627521        0.615         0.471      25.0      34.0               0
# 627522        0.615         0.471      25.0      34.0               0
# 627523        0.615         0.471      25.0      34.0               0
# 627524        0.615         0.471      25.0      34.0               0
# 627525        0.615         0.471      25.0      34.0               0
#
# [627526 rows x 49 columns]

# %%
#Buscamos el id de San Antonio
merge_games_gamesdetails.loc[merge_games_gamesdetails["TEAM_ABBREVIATION"] == 'SAS',["TEAM_ID"]].head(1)
# Out:
#         TEAM_ID
# 339  1610612759

# %%
#Una vez conocido el ID de SAS, filtramos el dataset de games_details para quedarnos solo con los datos de SAS. Lo guardamos en un nuevo dataset
df_SAS = arc_games_copia.loc[(arc_games_copia ["HOME_TEAM_ID"] == 1610612759) | (arc_games_copia ["VISITOR_TEAM_ID"] == 1610612759)]

# %%
#Analizamos el dataset de SAS
df_SAS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1769 entries, 13 to 24971
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GAME_DATE_EST    1769 non-null   object
#  1   GAME_ID          1769 non-null   int64
#  2   HOME_TEAM_ID     1769 non-null   int64
#  3   VISITOR_TEAM_ID  1769 non-null   int64
#  4   SEASON           1769 non-null   int64
#  5   HOME_TEAM_WINS   1769 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 96.7+ KB

# %%
#Seleccionamos las columnas que nos queremos quedar del dataset de SAS
df_SAS = df_SAS[["GAME_DATE_EST","GAME_ID","HOME_TEAM_ID","VISITOR_TEAM_ID","SEASON","HOME_TEAM_WINS"]]

# %%
#Creo el dataframe df_manu
df_manu_copia = pd.DataFrame()

# %%
#Tomamos el dataset con el merge original y filtramos el dataset de merge_games_details para quedarnos solo con los datos de Manu Ginobili. Lo guardamos en un nuevo dataset
df_manu_copia = merge_games_gamesdetails.loc[merge_games_gamesdetails["PLAYER_NAME"] == "Manu Ginobili"]

# %%
df_manu = df_manu_copia.copy()

# %%
#Analizamos el dataset que contiene los datos de Manu Ginobili
df_manu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1292 entries, 69945 to 626666
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GAME_ID            1292 non-null   int64
#  1   TEAM_ID            1292 non-null   int64
#  2   TEAM_ABBREVIATION  1292 non-null   object
#  3   TEAM_CITY          1292 non-null   object
#  4   PLAYER_ID          1292 non-null   int64
#  5   PLAYER_NAME        1292 non-null   object
#  6   NICKNAME           0 non-null      object
#  7   START_POSITION     397 non-null    object
#  8   COMMENT            57 non-null     object
#  9   MIN                1235 non-null   object
#  10  FGM                1235 non-null   float64
#  11  FGA                1235 non-null   float64
#  12  FG_PCT             1235 non-null   float64
#  13  FG3M               1235 non-null   float64
#  14  FG3A               1235 non-null   float64
#  15  FG3_PCT            1235 non-null   float64
#  16  FTM                1235 non-null   float64
#  17  FTA                1235 non-null   float64
#  18  FT_PCT             1235 non-null   float64
#  19  OREB               1235 non-null   float64
#  20  DREB               1235 non-null   float64
#  21  REB                1235 non-null   float64
#  22  AST                1235 non-null   float64
#  23  STL                1235 non-null   float64
#  24  BLK                1235 non-null   float64
#  25  TO                 1235 non-null   float64
#  26  PF                 1235 non-null   float64
#  27  PTS                1235 non-null   float64
#  28  PLUS_MINUS         1199 non-null   float64
#  29  GAME_DATE_EST      1292 non-null   object
#  30  GAME_STATUS_TEXT   1292 non-null   object
#  31  HOME_TEAM_ID       1292 non-null   int64
#  32  VISITOR_TEAM_ID    1292 non-null   int64
#  33  SEASON             1292 non-null   int64
#  34  TEAM_ID_home       1292 non-null   int64
#  35  PTS_home           1292 non-null   float64
#  36  FG_PCT_home        1292 non-null   float64
#  37  FT_PCT_home        1292 non-null   float64
#  38  FG3_PCT_home       1292 non-null   float64
#  39  AST_home           1292 non-null   float64
#  40  REB_home           1292 non-null   float64
#  41  TEAM_ID_away       1292 non-null   int64
#  42  PTS_away           1292 non-null   float64
#  43  FG_PCT_away        1292 non-null   float64
#  44  FT_PCT_away        1292 non-null   float64
#  45  FG3_PCT_away       1292 non-null   float64
#  46  AST_away           1292 non-null   float64
#  47  REB_away           1292 non-null   float64
#  48  HOME_TEAM_WINS     1292 non-null   int64
# dtypes: float64(31), int64(9), object(9)
# memory usage: 504.7+ KB

# %%
#Creamos una funcion que nos indique las etapas de la carrera de Manu

def etapas(temporada):
    if temporada == 2003:
        return "2003 - Rookie"
    elif temporada == 2004: 
        return "2004 - Sophomore"
    elif temporada < 2013: 
        return "2005 a 2012 - Media"
    else: 
        return "2013 a 2017 - Senior"

# %%
#Agregamos la columna Etapa usando la funcion creada

df_manu['Etapa'] = df_manu.apply(lambda x: etapas(x["SEASON"]),axis=1)

# %%
df_manu[["SEASON","Etapa"]]
# Out:
#         SEASON                Etapa
# 69945     2008  2005 a 2012 - Media
# 70304     2008  2005 a 2012 - Media
# 70676     2008  2005 a 2012 - Media
# 71026     2008  2005 a 2012 - Media
# 71422     2008  2005 a 2012 - Media
# ...        ...                  ...
# 623704    2012  2005 a 2012 - Media
# 624040    2012  2005 a 2012 - Media
# 625682    2012  2005 a 2012 - Media
# 625855    2012  2005 a 2012 - Media
# 626666    2012  2005 a 2012 - Media
#
# [1292 rows x 2 columns]

# %%
#Creamos una funcion que nos indique la estacion del año en la que se realizó el partido

def estacion(mes):
    if mes == 12 or mes == 1 or mes == 2:
        return "Invierno"
    elif mes == 3 or mes == 4 or mes == 5:
        return "Primavera"
    elif mes == 6 or mes == 7 or mes == 8:
        return "Verano"
    else:     
        return "Otoño"

# %%
df_manu[['año','mes','dia']] = df_manu['GAME_DATE_EST'].str.split('-', 2, expand = True)

# %%
df_manu[['año','mes','dia']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1292 entries, 69945 to 626666
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   año     1292 non-null   object
#  1   mes     1292 non-null   object
#  2   dia     1292 non-null   object
# dtypes: object(3)
# memory usage: 40.4+ KB

# %%
df_manu["mes"] = df_manu["mes"].astype("int")

# %%
df_manu[['año','mes','dia']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1292 entries, 69945 to 626666
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   año     1292 non-null   object
#  1   mes     1292 non-null   int32
#  2   dia     1292 non-null   object
# dtypes: int32(1), object(2)
# memory usage: 35.3+ KB

# %%
df_manu['mes']
# Out:
# 69945      4
# 70304      4
# 70676      3
# 71026      3
# 71422      3
#           ..
# 623704    11
# 624040    11
# 625682    10
# 625855    10
# 626666    10
# Name: mes, Length: 1292, dtype: int32

# %%
df_manu['Estacion'] = df_manu.apply(lambda x: estacion(x["mes"]),axis=1)

# %%
df_manu['Estacion'].sample(30)
# Out:
# 216217     Invierno
# 585227        Otoño
# 143008    Primavera
# 438576        Otoño
# 475115        Otoño
# 545338        Otoño
# 573998     Invierno
# 218974     Invierno
# 531063     Invierno
# 531969     Invierno
# 321685        Otoño
# 337160    Primavera
# 445394    Primavera
# 352678     Invierno
# 89674      Invierno
# 277092    Primavera
# 105930    Primavera
# 313063     Invierno
# 199609        Otoño
# 80693      Invierno
# 233983        Otoño
# 613382     Invierno
# 145404     Invierno
# 183492     Invierno
# 261485        Otoño
# 175481    Primavera
# 90718      Invierno
# 351971     Invierno
# 100344    Primavera
# 467190     Invierno
# Name: Estacion, dtype: object

# %%
#Ordenamos el Dataset por temporada
df_manu = df_manu.sort_values(by = ["SEASON"])

# %%
#Reseteamos el indice
df_manu = df_manu.reset_index()

# %%
df_manu
# Out:
#        index   GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0     249058  20300689  1610612759               SAS  San Antonio       1938
# 1     241187  20301020  1610612759               SAS  San Antonio       1938
# 2     241652  20301001  1610612759               SAS  San Antonio       1938
# 3     241985  20300985  1610612759               SAS  San Antonio       1938
# 4     242426  20300965  1610612759               SAS  San Antonio       1938
# ...      ...       ...         ...               ...          ...        ...
# 1287  432808  21700323  1610612759               SAS  San Antonio       1938
# 1288  433225  21700311  1610612759               SAS  San Antonio       1938
# 1289  433530  21700295  1610612759               SAS  San Antonio       1938
# 1290  434622  21700250  1610612759               SAS  San Antonio       1938
# 1291  433672  21700277  1610612759               SAS  San Antonio       1938
#
#         PLAYER_NAME NICKNAME START_POSITION COMMENT  ... FT_PCT_away  \
# 0     Manu Ginobili      NaN            NaN     NaN  ...       0.600
# 1     Manu Ginobili      NaN            NaN     NaN  ...       0.643
# 2     Manu Ginobili      NaN            NaN     NaN  ...       0.929
# 3     Manu Ginobili      NaN            NaN     NaN  ...       0.846
# 4     Manu Ginobili      NaN            NaN     NaN  ...       0.759
# ...             ...      ...            ...     ...  ...         ...
# 1287  Manu Ginobili      NaN            NaN     NaN  ...       0.688
# 1288  Manu Ginobili      NaN            NaN     NaN  ...       0.875
# 1289  Manu Ginobili      NaN            NaN     NaN  ...       0.706
# 1290  Manu Ginobili      NaN            NaN     NaN  ...       0.375
# 1291  Manu Ginobili      NaN            NaN     NaN  ...       0.880
#
#       FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS                 Etapa  \
# 0            0.250      15.0      40.0               0         2003 - Rookie
# 1            0.167      28.0      48.0               1         2003 - Rookie
# 2            0.429      17.0      31.0               1         2003 - Rookie
# 3            0.222      15.0      37.0               1         2003 - Rookie
# 4            0.364      14.0      37.0               1         2003 - Rookie
# ...            ...       ...       ...             ...                   ...
# 1287         0.407      20.0      43.0               0  2013 a 2017 - Senior
# 1288         0.500      21.0      37.0               1  2013 a 2017 - Senior
# 1289         0.438      25.0      40.0               1  2013 a 2017 - Senior
# 1290         0.267      21.0      38.0               1  2013 a 2017 - Senior
# 1291         0.240      22.0      45.0               0  2013 a 2017 - Senior
#
#        año  mes  dia   Estacion
# 0     2004    2   02   Invierno
# 1     2004    3   23  Primavera
# 2     2004    3   20  Primavera
# 3     2004    3   18  Primavera
# 4     2004    3   15  Primavera
# ...    ...  ...  ...        ...
# 1287  2017   12   01   Invierno
# 1288  2017   11   29      Otoño
# 1289  2017   11   27      Otoño
# 1290  2017   11   20      Otoño
# 1291  2017   11   25      Otoño
#
# [1292 rows x 55 columns]

# %%
#Completamos los valores nulos de la columna MIN
df_manu[["MIN"]] = df_manu[["MIN"]].fillna(0)

# %%
#Subdividmos la columna MIN debido al formato ", y creamos las columnas minutos y segundos 
df_manu[['minutos','segundos']] = df_manu['MIN'].str.split(':', 1, expand = True)

# %%
#Verificamos si hay valores nulos en mintutos
df_manu.loc[df_manu["minutos"].isnull()]
# Out:
#        index   GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 94    206623  20401145  1610612759               SAS  San Antonio       1938
# 99    211012  20400966  1610612759               SAS  San Antonio       1938
# 100   211372  20400951  1610612759               SAS  San Antonio       1938
# 101   211734  20400935  1610612759               SAS  San Antonio       1938
# 102   212094  20400918  1610612759               SAS  San Antonio       1938
# 103   212487  20400900  1610612759               SAS  San Antonio       1938
# 179   220890  20400550  1610612759               SAS  San Antonio       1938
# 187   223931  20400420  1610612759               SAS  San Antonio       1938
# 218   176180  20500978  1610612759               SAS  San Antonio       1938
# 278   171450  20501175  1610612759               SAS  San Antonio       1938
# 422   102780  20701198  1610612759               SAS  San Antonio       1938
# 423   103105  20701185  1610612759               SAS  San Antonio       1938
# 564   333400  20901098  1610612759               SAS  San Antonio       1938
# 565   330520  20901220  1610612759               SAS  San Antonio       1938
# 711   271653  21100850  1610612759               SAS  San Antonio       1938
# 762   605431  21200766  1610612759               SAS  San Antonio       1938
# 785   605586  21200758  1610612759               SAS  San Antonio       1938
# 796   606047  21200739  1610612759               SAS  San Antonio       1938
# 798   607061  21200702  1610612759               SAS  San Antonio       1938
# 802   619231  21200220  1610612759               SAS  San Antonio       1938
# 819   606277  21200731  1610612759               SAS  San Antonio       1938
# 839   615869  21200354  1610612759               SAS  San Antonio       1938
# 847   559898  21301127  1610612759               SAS  San Antonio       1938
# 853   562213  21301038  1610612759               SAS  San Antonio       1938
# 929   574466  21300554  1610612759               SAS  San Antonio       1938
# 930   575323  21300520  1610612759               SAS  San Antonio       1938
# 939   578847  21300382  1610612759               SAS  San Antonio       1938
# 998   549425  21400069  1610612759               SAS  San Antonio       1938
# 1005  553036  11400062  1610612759               SAS  San Antonio       1938
# 1018  541074  21400397  1610612759               SAS  San Antonio       1938
# 1021  541967  21400361  1610612759               SAS  San Antonio       1938
# 1024  542950  21400322  1610612759               SAS  San Antonio       1938
# 1026  543774  21400291  1610612759               SAS  San Antonio       1938
# 1053  516945  11500027  1610612759               SAS  San Antonio       1938
# 1104  506349  21500305  1610612759               SAS  San Antonio       1938
# 1148  446849  21601183  1610612759               SAS  San Antonio       1938
# 1149  447249  21601170  1610612759               SAS  San Antonio       1938
# 1151  447813  21601151  1610612759               SAS  San Antonio       1938
# 1155  460028  21600666  1610612759               SAS  San Antonio       1938
# 1169  477294  11600101  1610612759               SAS  San Antonio       1938
# 1174  480438  11600007  1610612759               SAS  San Antonio       1938
# 1195  469051  21600319  1610612759               SAS  San Antonio       1938
# 1203  424356  21700655  1610612759               SAS  San Antonio       1938
# 1205  418456  21700894  1610612759               SAS  San Antonio       1938
# 1215  422761  21700722  1610612759               SAS  San Antonio       1938
# 1217  423335  21700698  1610612759               SAS  San Antonio       1938
# 1218  423714  21700686  1610612759               SAS  San Antonio       1938
# 1219  424104  21700667  1610612759               SAS  San Antonio       1938
# 1221  423123  21700707  1610612759               SAS  San Antonio       1938
# 1249  436194  21700183  1610612759               SAS  San Antonio       1938
# 1252  437253  21700141  1610612759               SAS  San Antonio       1938
# 1255  438576  21700092  1610612759               SAS  San Antonio       1938
# 1265  442451  11700036  1610612759               SAS  San Antonio       1938
# 1268  425931  21700596  1610612759               SAS  San Antonio       1938
# 1272  426879  21700555  1610612759               SAS  San Antonio       1938
# 1278  429149  21700470  1610612759               SAS  San Antonio       1938
# 1286  432408  21700337  1610612759               SAS  San Antonio       1938
#
#         PLAYER_NAME NICKNAME START_POSITION  \
# 94    Manu Ginobili      NaN            NaN
# 99    Manu Ginobili      NaN            NaN
# 100   Manu Ginobili      NaN            NaN
# 101   Manu Ginobili      NaN            NaN
# 102   Manu Ginobili      NaN            NaN
# 103   Manu Ginobili      NaN            NaN
# 179   Manu Ginobili      NaN            NaN
# 187   Manu Ginobili      NaN            NaN
# 218   Manu Ginobili      NaN            NaN
# 278   Manu Ginobili      NaN            NaN
# 422   Manu Ginobili      NaN            NaN
# 423   Manu Ginobili      NaN            NaN
# 564   Manu Ginobili      NaN            NaN
# 565   Manu Ginobili      NaN            NaN
# 711   Manu Ginobili      NaN            NaN
# 762   Manu Ginobili      NaN            NaN
# 785   Manu Ginobili      NaN            NaN
# 796   Manu Ginobili      NaN            NaN
# 798   Manu Ginobili      NaN            NaN
# 802   Manu Ginobili      NaN            NaN
# 819   Manu Ginobili      NaN            NaN
# 839   Manu Ginobili      NaN            NaN
# 847   Manu Ginobili      NaN            NaN
# 853   Manu Ginobili      NaN            NaN
# 929   Manu Ginobili      NaN            NaN
# 930   Manu Ginobili      NaN            NaN
# 939   Manu Ginobili      NaN            NaN
# 998   Manu Ginobili      NaN            NaN
# 1005  Manu Ginobili      NaN            NaN
# 1018  Manu Ginobili      NaN            NaN
# 1021  Manu Ginobili      NaN            NaN
# 1024  Manu Ginobili      NaN            NaN
# 1026  Manu Ginobili      NaN            NaN
# 1053  Manu Ginobili      NaN            NaN
# 1104  Manu Ginobili      NaN            NaN
# 1148  Manu Ginobili      NaN            NaN
# 1149  Manu Ginobili      NaN            NaN
# 1151  Manu Ginobili      NaN            NaN
# 1155  Manu Ginobili      NaN            NaN
# 1169  Manu Ginobili      NaN            NaN
# 1174  Manu Ginobili      NaN            NaN
# 1195  Manu Ginobili      NaN            NaN
# 1203  Manu Ginobili      NaN            NaN
# 1205  Manu Ginobili      NaN            NaN
# 1215  Manu Ginobili      NaN            NaN
# 1217  Manu Ginobili      NaN            NaN
# 1218  Manu Ginobili      NaN            NaN
# 1219  Manu Ginobili      NaN            NaN
# 1221  Manu Ginobili      NaN            NaN
# 1249  Manu Ginobili      NaN            NaN
# 1252  Manu Ginobili      NaN            NaN
# 1255  Manu Ginobili      NaN            NaN
# 1265  Manu Ginobili      NaN            NaN
# 1268  Manu Ginobili      NaN            NaN
# 1272  Manu Ginobili      NaN            NaN
# 1278  Manu Ginobili      NaN            NaN
# 1286  Manu Ginobili      NaN            NaN
#
#                                        COMMENT  ... AST_away  REB_away  \
# 94                         DND - Stomach Virus  ...     24.0      59.0
# 99                  DND - Strained Right Groin  ...     13.0      49.0
# 100                 DND - Strained right groin  ...     14.0      44.0
# 101                 DND - strained right groin  ...     21.0      37.0
# 102            DND - slight right groin strain  ...     14.0      38.0
# 103                DND - Right Groin Tightness  ...     15.0      37.0
# 179            DND - right quadricep contusion  ...     16.0      37.0
# 187                          DND-strained neck  ...     34.0      49.0
# 218                  DNP - Calf/quad contusion  ...     19.0      37.0
# 278                     DNP - Coach's Decision  ...     15.0      39.0
# 422          DND - Mild strain, left adductor.  ...     20.0      36.0
# 423           DND - mild strain, left adductor  ...     13.0      46.0
# 564                          DND - Back Spasms  ...     23.0      53.0
# 565                     DND - Coach's Decision  ...     18.0      52.0
# 711                                      NWT -  ...     16.0      38.0
# 762                     DNP - Coach's Decision  ...     21.0      26.0
# 785                     DNP - Coach's Decision  ...     22.0      28.0
# 796                     DNP - Coach's Decision  ...     20.0      33.0
# 798             DND - Tightness left hamstring  ...     24.0      41.0
# 802                                      NWT -  ...     22.0      45.0
# 819                     DNP - Coach's Decision  ...     24.0      41.0
# 839                  DND - Left Quad Contusion  ...     23.0      37.0
# 847                                 DND - Rest  ...     18.0      42.0
# 853                     DNP - Coach's Decision  ...     24.0      40.0
# 929             DND - Tightness Left hamstring  ...     17.0      40.0
# 930            DND - tightness, left hamstring  ...     20.0      32.0
# 939                     DNP - Coach's Decision  ...     21.0      39.0
# 998   DNP - Coach's Decision                    ...     17.0      41.0
# 1005  NWT - Coach's Decision                    ...     20.0      41.0
# 1018  DNP - Coach's Decision                    ...     10.0      48.0
# 1021  DNP - Coach's Decision                    ...     19.0      42.0
# 1024  DND - rest                                ...     22.0      36.0
# 1026  DND - Left shoulder impingement           ...     20.0      33.0
# 1053  NWT - rehabilitation and rest             ...     19.0      38.0
# 1104  DNP - Coach's Decision                    ...     32.0      47.0
# 1148  NWT - Rest                                ...     26.0      58.0
# 1149  DND - Right quad contusion                ...     23.0      47.0
# 1151  DNP - Coach's Decision                    ...     24.0      36.0
# 1155  DNP - Coach's Decision                    ...     22.0      50.0
# 1169  DNP - Coach's Decision                    ...     20.0      46.0
# 1174  NWT - Did Not Travel                      ...     17.0      41.0
# 1195  DNP - Coach's Decision                    ...     21.0      35.0
# 1203  DNP - Injury/Illness                      ...     24.0      42.0
# 1205  DNP - Coach's Decision                    ...     22.0      44.0
# 1215  DNP - Injury/Illness                      ...     23.0      50.0
# 1217  DNP - Injury/Illness                      ...     19.0      41.0
# 1218  DNP - Injury/Illness                      ...     14.0      41.0
# 1219  NWT - Injury/Illness                      ...     18.0      56.0
# 1221  NWT - Injury/Illness                      ...     29.0      45.0
# 1249  DND - Rest                                ...     22.0      28.0
# 1252  DND - Rest                                ...     23.0      45.0
# 1255  DND - Rest                                ...     24.0      40.0
# 1265  DNP - Coach's Decision                    ...     19.0      32.0
# 1268  DNP - Coach's Decision                    ...     23.0      37.0
# 1272  DNP - Coach's Decision                    ...     15.0      43.0
# 1278  DND - Rest                                ...     14.0      38.0
# 1286  DNP - Coach's Decision                    ...     14.0      39.0
#
#       HOME_TEAM_WINS                 Etapa   año  mes  dia   Estacion  \
# 94                 0      2004 - Sophomore  2005    4   10  Primavera
# 99                 1      2004 - Sophomore  2005    3   18  Primavera
# 100                1      2004 - Sophomore  2005    3   16  Primavera
# 101                1      2004 - Sophomore  2005    3   14  Primavera
# 102                0      2004 - Sophomore  2005    3   12  Primavera
# 103                1      2004 - Sophomore  2005    3   09  Primavera
# 179                1      2004 - Sophomore  2005    1   17   Invierno
# 187                0      2004 - Sophomore  2004   12   30   Invierno
# 218                0   2005 a 2012 - Media  2006    3   18  Primavera
# 278                0   2005 a 2012 - Media  2006    4   13  Primavera
# 422                1   2005 a 2012 - Media  2008    4   13  Primavera
# 423                1   2005 a 2012 - Media  2008    4   11  Primavera
# 564                1   2005 a 2012 - Media  2010    3   29  Primavera
# 565                1   2005 a 2012 - Media  2010    4   14  Primavera
# 711                1   2005 a 2012 - Media  2012    4   09  Primavera
# 762                0   2005 a 2012 - Media  2013    2   11   Invierno
# 785                0   2005 a 2012 - Media  2013    2   10   Invierno
# 796                1   2005 a 2012 - Media  2013    2   08   Invierno
# 798                1   2005 a 2012 - Media  2013    2   02   Invierno
# 802                1   2005 a 2012 - Media  2012   11   29      Otoño
# 819                0   2005 a 2012 - Media  2013    2   06   Invierno
# 839                1   2005 a 2012 - Media  2012   12   17   Invierno
# 847                1  2013 a 2017 - Senior  2014    4   03  Primavera
# 853                0  2013 a 2017 - Senior  2014    3   22  Primavera
# 929                1  2013 a 2017 - Senior  2014    1   12   Invierno
# 930                1  2013 a 2017 - Senior  2014    1   08   Invierno
# 939                0  2013 a 2017 - Senior  2013   12   19   Invierno
# 998                1  2013 a 2017 - Senior  2014   11   06      Otoño
# 1005               1  2013 a 2017 - Senior  2014   10   16      Otoño
# 1018               1  2013 a 2017 - Senior  2014   12   20   Invierno
# 1021               1  2013 a 2017 - Senior  2014   12   15   Invierno
# 1024               1  2013 a 2017 - Senior  2014   12   10   Invierno
# 1026               1  2013 a 2017 - Senior  2014   12   06   Invierno
# 1053               1  2013 a 2017 - Senior  2015   10   08      Otoño
# 1104               0  2013 a 2017 - Senior  2015   12   07   Invierno
# 1148               0  2013 a 2017 - Senior  2017    4   07  Primavera
# 1149               0  2013 a 2017 - Senior  2017    4   05  Primavera
# 1151               1  2013 a 2017 - Senior  2017    4   02  Primavera
# 1155               0  2013 a 2017 - Senior  2017    1   23   Invierno
# 1169               1  2013 a 2017 - Senior  2016   10   21      Otoño
# 1174               1  2013 a 2017 - Senior  2016   10   03      Otoño
# 1195               0  2013 a 2017 - Senior  2016   12   06   Invierno
# 1203               0  2013 a 2017 - Senior  2018    1   17   Invierno
# 1205               0  2013 a 2017 - Senior  2018    2   25   Invierno
# 1215               0  2013 a 2017 - Senior  2018    1   26   Invierno
# 1217               1  2013 a 2017 - Senior  2018    1   23   Invierno
# 1218               0  2013 a 2017 - Senior  2018    1   21   Invierno
# 1219               1  2013 a 2017 - Senior  2018    1   19   Invierno
# 1221               0  2013 a 2017 - Senior  2018    1   24   Invierno
# 1249               1  2013 a 2017 - Senior  2017   11   11      Otoño
# 1252               1  2013 a 2017 - Senior  2017   11   05      Otoño
# 1255               1  2013 a 2017 - Senior  2017   10   30      Otoño
# 1265               1  2013 a 2017 - Senior  2017   10   06      Otoño
# 1268               0  2013 a 2017 - Senior  2018    1   08   Invierno
# 1272               1  2013 a 2017 - Senior  2018    1   03   Invierno
# 1278               1  2013 a 2017 - Senior  2017   12   21   Invierno
# 1286               1  2013 a 2017 - Senior  2017   12   03   Invierno
#
#       minutos  segundos
# 94        NaN       NaN
# 99        NaN       NaN
# 100       NaN       NaN
# 101       NaN       NaN
# 102       NaN       NaN
# 103       NaN       NaN
# 179       NaN       NaN
# 187       NaN       NaN
# 218       NaN       NaN
# 278       NaN       NaN
# 422       NaN       NaN
# 423       NaN       NaN
# 564       NaN       NaN
# 565       NaN       NaN
# 711       NaN       NaN
# 762       NaN       NaN
# 785       NaN       NaN
# 796       NaN       NaN
# 798       NaN       NaN
# 802       NaN       NaN
# 819       NaN       NaN
# 839       NaN       NaN
# 847       NaN       NaN
# 853       NaN       NaN
# 929       NaN       NaN
# 930       NaN       NaN
# 939       NaN       NaN
# 998       NaN       NaN
# 1005      NaN       NaN
# 1018      NaN       NaN
# 1021      NaN       NaN
# 1024      NaN       NaN
# 1026      NaN       NaN
# 1053      NaN       NaN
# 1104      NaN       NaN
# 1148      NaN       NaN
# 1149      NaN       NaN
# 1151      NaN       NaN
# 1155      NaN       NaN
# 1169      NaN       NaN
# 1174      NaN       NaN
# 1195      NaN       NaN
# 1203      NaN       NaN
# 1205      NaN       NaN
# 1215      NaN       NaN
# 1217      NaN       NaN
# 1218      NaN       NaN
# 1219      NaN       NaN
# 1221      NaN       NaN
# 1249      NaN       NaN
# 1252      NaN       NaN
# 1255      NaN       NaN
# 1265      NaN       NaN
# 1268      NaN       NaN
# 1272      NaN       NaN
# 1278      NaN       NaN
# 1286      NaN       NaN
#
# [57 rows x 57 columns]

# %%
# Completamos los valores nulos de minutos y segundos y transformamos las columnas a float
df_manu[["minutos"]] = df_manu[["minutos"]].fillna(0)
df_manu[["segundos"]] = df_manu[["segundos"]].fillna(0)
df_manu[["minutos"]] = df_manu[["minutos"]].astype(float).round(2)
df_manu[["segundos"]] = df_manu[["segundos"]].astype(float).round(2)

# %%
df_manu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292 entries, 0 to 1291
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1292 non-null   int64
#  1   GAME_ID            1292 non-null   int64
#  2   TEAM_ID            1292 non-null   int64
#  3   TEAM_ABBREVIATION  1292 non-null   object
#  4   TEAM_CITY          1292 non-null   object
#  5   PLAYER_ID          1292 non-null   int64
#  6   PLAYER_NAME        1292 non-null   object
#  7   NICKNAME           0 non-null      object
#  8   START_POSITION     397 non-null    object
#  9   COMMENT            57 non-null     object
#  10  MIN                1292 non-null   object
#  11  FGM                1235 non-null   float64
#  12  FGA                1235 non-null   float64
#  13  FG_PCT             1235 non-null   float64
#  14  FG3M               1235 non-null   float64
#  15  FG3A               1235 non-null   float64
#  16  FG3_PCT            1235 non-null   float64
#  17  FTM                1235 non-null   float64
#  18  FTA                1235 non-null   float64
#  19  FT_PCT             1235 non-null   float64
#  20  OREB               1235 non-null   float64
#  21  DREB               1235 non-null   float64
#  22  REB                1235 non-null   float64
#  23  AST                1235 non-null   float64
#  24  STL                1235 non-null   float64
#  25  BLK                1235 non-null   float64
#  26  TO                 1235 non-null   float64
#  27  PF                 1235 non-null   float64
#  28  PTS                1235 non-null   float64
#  29  PLUS_MINUS         1199 non-null   float64
#  30  GAME_DATE_EST      1292 non-null   object
#  31  GAME_STATUS_TEXT   1292 non-null   object
#  32  HOME_TEAM_ID       1292 non-null   int64
#  33  VISITOR_TEAM_ID    1292 non-null   int64
#  34  SEASON             1292 non-null   int64
#  35  TEAM_ID_home       1292 non-null   int64
#  36  PTS_home           1292 non-null   float64
#  37  FG_PCT_home        1292 non-null   float64
#  38  FT_PCT_home        1292 non-null   float64
#  39  FG3_PCT_home       1292 non-null   float64
#  40  AST_home           1292 non-null   float64
#  41  REB_home           1292 non-null   float64
#  42  TEAM_ID_away       1292 non-null   int64
#  43  PTS_away           1292 non-null   float64
#  44  FG_PCT_away        1292 non-null   float64
#  45  FT_PCT_away        1292 non-null   float64
#  46  FG3_PCT_away       1292 non-null   float64
#  47  AST_away           1292 non-null   float64
#  48  REB_away           1292 non-null   float64
#  49  HOME_TEAM_WINS     1292 non-null   int64
#  50  Etapa              1292 non-null   object
#  51  año                1292 non-null   object
#  52  mes                1292 non-null   int32
#  53  dia                1292 non-null   object
#  54  Estacion           1292 non-null   object
#  55  minutos            1292 non-null   float64
#  56  segundos           1292 non-null   float64
# dtypes: float64(33), int32(1), int64(10), object(13)
# memory usage: 570.4+ KB

# %%
df_manu["edad"] = df_manu["SEASON"] - 1977

# %%
df_manu
# Out:
#        index   GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0     249058  20300689  1610612759               SAS  San Antonio       1938
# 1     241187  20301020  1610612759               SAS  San Antonio       1938
# 2     241652  20301001  1610612759               SAS  San Antonio       1938
# 3     241985  20300985  1610612759               SAS  San Antonio       1938
# 4     242426  20300965  1610612759               SAS  San Antonio       1938
# ...      ...       ...         ...               ...          ...        ...
# 1287  432808  21700323  1610612759               SAS  San Antonio       1938
# 1288  433225  21700311  1610612759               SAS  San Antonio       1938
# 1289  433530  21700295  1610612759               SAS  San Antonio       1938
# 1290  434622  21700250  1610612759               SAS  San Antonio       1938
# 1291  433672  21700277  1610612759               SAS  San Antonio       1938
#
#         PLAYER_NAME NICKNAME START_POSITION COMMENT  ... REB_away  \
# 0     Manu Ginobili      NaN            NaN     NaN  ...     40.0
# 1     Manu Ginobili      NaN            NaN     NaN  ...     48.0
# 2     Manu Ginobili      NaN            NaN     NaN  ...     31.0
# 3     Manu Ginobili      NaN            NaN     NaN  ...     37.0
# 4     Manu Ginobili      NaN            NaN     NaN  ...     37.0
# ...             ...      ...            ...     ...  ...      ...
# 1287  Manu Ginobili      NaN            NaN     NaN  ...     43.0
# 1288  Manu Ginobili      NaN            NaN     NaN  ...     37.0
# 1289  Manu Ginobili      NaN            NaN     NaN  ...     40.0
# 1290  Manu Ginobili      NaN            NaN     NaN  ...     38.0
# 1291  Manu Ginobili      NaN            NaN     NaN  ...     45.0
#
#       HOME_TEAM_WINS                 Etapa   año  mes  dia   Estacion  \
# 0                  0         2003 - Rookie  2004    2   02   Invierno
# 1                  1         2003 - Rookie  2004    3   23  Primavera
# 2                  1         2003 - Rookie  2004    3   20  Primavera
# 3                  1         2003 - Rookie  2004    3   18  Primavera
# 4                  1         2003 - Rookie  2004    3   15  Primavera
# ...              ...                   ...   ...  ...  ...        ...
# 1287               0  2013 a 2017 - Senior  2017   12   01   Invierno
# 1288               1  2013 a 2017 - Senior  2017   11   29      Otoño
# 1289               1  2013 a 2017 - Senior  2017   11   27      Otoño
# 1290               1  2013 a 2017 - Senior  2017   11   20      Otoño
# 1291               0  2013 a 2017 - Senior  2017   11   25      Otoño
#
#       minutos  segundos  edad
# 0        24.0      50.0    26
# 1        20.0      45.0    26
# 2        23.0      38.0    26
# 3        28.0       2.0    26
# 4        24.0      38.0    26
# ...       ...       ...   ...
# 1287     24.0      37.0    40
# 1288     23.0      35.0    40
# 1289     16.0      55.0    40
# 1290     25.0      38.0    40
# 1291     19.0      58.0    40
#
# [1292 rows x 58 columns]

# %%
def posicion(comentario,pos):
    if pd.isna(comentario):
        if pd.isna(pos):
            return "Suplente"
        else:
            return pos    
    else:
        return "No Jugo"

# %%
df_manu
# Out:
#        index   GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0     249058  20300689  1610612759               SAS  San Antonio       1938
# 1     241187  20301020  1610612759               SAS  San Antonio       1938
# 2     241652  20301001  1610612759               SAS  San Antonio       1938
# 3     241985  20300985  1610612759               SAS  San Antonio       1938
# 4     242426  20300965  1610612759               SAS  San Antonio       1938
# ...      ...       ...         ...               ...          ...        ...
# 1287  432808  21700323  1610612759               SAS  San Antonio       1938
# 1288  433225  21700311  1610612759               SAS  San Antonio       1938
# 1289  433530  21700295  1610612759               SAS  San Antonio       1938
# 1290  434622  21700250  1610612759               SAS  San Antonio       1938
# 1291  433672  21700277  1610612759               SAS  San Antonio       1938
#
#         PLAYER_NAME NICKNAME START_POSITION COMMENT  ... REB_away  \
# 0     Manu Ginobili      NaN            NaN     NaN  ...     40.0
# 1     Manu Ginobili      NaN            NaN     NaN  ...     48.0
# 2     Manu Ginobili      NaN            NaN     NaN  ...     31.0
# 3     Manu Ginobili      NaN            NaN     NaN  ...     37.0
# 4     Manu Ginobili      NaN            NaN     NaN  ...     37.0
# ...             ...      ...            ...     ...  ...      ...
# 1287  Manu Ginobili      NaN            NaN     NaN  ...     43.0
# 1288  Manu Ginobili      NaN            NaN     NaN  ...     37.0
# 1289  Manu Ginobili      NaN            NaN     NaN  ...     40.0
# 1290  Manu Ginobili      NaN            NaN     NaN  ...     38.0
# 1291  Manu Ginobili      NaN            NaN     NaN  ...     45.0
#
#       HOME_TEAM_WINS                 Etapa   año  mes  dia   Estacion  \
# 0                  0         2003 - Rookie  2004    2   02   Invierno
# 1                  1         2003 - Rookie  2004    3   23  Primavera
# 2                  1         2003 - Rookie  2004    3   20  Primavera
# 3                  1         2003 - Rookie  2004    3   18  Primavera
# 4                  1         2003 - Rookie  2004    3   15  Primavera
# ...              ...                   ...   ...  ...  ...        ...
# 1287               0  2013 a 2017 - Senior  2017   12   01   Invierno
# 1288               1  2013 a 2017 - Senior  2017   11   29      Otoño
# 1289               1  2013 a 2017 - Senior  2017   11   27      Otoño
# 1290               1  2013 a 2017 - Senior  2017   11   20      Otoño
# 1291               0  2013 a 2017 - Senior  2017   11   25      Otoño
#
#       minutos  segundos  edad
# 0        24.0      50.0    26
# 1        20.0      45.0    26
# 2        23.0      38.0    26
# 3        28.0       2.0    26
# 4        24.0      38.0    26
# ...       ...       ...   ...
# 1287     24.0      37.0    40
# 1288     23.0      35.0    40
# 1289     16.0      55.0    40
# 1290     25.0      38.0    40
# 1291     19.0      58.0    40
#
# [1292 rows x 58 columns]

# %%
df_manu["COMMENT"].isnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1287    True
# 1288    True
# 1289    True
# 1290    True
# 1291    True
# Name: COMMENT, Length: 1292, dtype: bool

# %%
df_manu['Posicion'] = df_manu.apply(lambda x: posicion(x["COMMENT"],x["START_POSITION"]),axis=1)

# %%
df_manu.loc[df_manu["START_POSITION"].notnull()]
# Out:
#        index   GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 44    250149  20300641  1610612759               SAS  San Antonio       1938
# 45    259724  20300240  1610612759               SAS  San Antonio       1938
# 46    259988  20300232  1610612759               SAS  San Antonio       1938
# 47    260371  20300222  1610612759               SAS  San Antonio       1938
# 48    260649  20300205  1610612759               SAS  San Antonio       1938
# ...      ...       ...         ...               ...          ...        ...
# 817   591329  41200407  1610612759               SAS  San Antonio       1938
# 852   561808  21301054  1610612759               SAS  San Antonio       1938
# 927   573998  21300573  1610612759               SAS  San Antonio       1938
# 928   574366  21300559  1610612759               SAS  San Antonio       1938
# 1176  443756  41600314  1610612759               SAS  San Antonio       1938
#
#         PLAYER_NAME NICKNAME START_POSITION COMMENT  ... HOME_TEAM_WINS  \
# 44    Manu Ginobili      NaN              G     NaN  ...              0
# 45    Manu Ginobili      NaN              G     NaN  ...              1
# 46    Manu Ginobili      NaN              G     NaN  ...              1
# 47    Manu Ginobili      NaN              G     NaN  ...              1
# 48    Manu Ginobili      NaN              G     NaN  ...              1
# ...             ...      ...            ...     ...  ...            ...
# 817   Manu Ginobili      NaN              F     NaN  ...              1
# 852   Manu Ginobili      NaN              G     NaN  ...              1
# 927   Manu Ginobili      NaN              G     NaN  ...              1
# 928   Manu Ginobili      NaN              G     NaN  ...              0
# 1176  Manu Ginobili      NaN              F     NaN  ...              0
#
#                      Etapa   año  mes  dia   Estacion  minutos  segundos  \
# 44           2003 - Rookie  2004    1   27   Invierno     36.0      14.0
# 45           2003 - Rookie  2003   12   01   Invierno     40.0      35.0
# 46           2003 - Rookie  2003   11   29      Otoño     32.0       4.0
# 47           2003 - Rookie  2003   11   28      Otoño     25.0      45.0
# 48           2003 - Rookie  2003   11   26      Otoño     31.0      34.0
# ...                    ...   ...  ...  ...        ...      ...       ...
# 817    2005 a 2012 - Media  2013    6   20     Verano     35.0       5.0
# 852   2013 a 2017 - Senior  2014    3   24  Primavera     26.0      22.0
# 927   2013 a 2017 - Senior  2014    1   15   Invierno     20.0      43.0
# 928   2013 a 2017 - Senior  2014    1   13   Invierno     24.0      37.0
# 1176  2013 a 2017 - Senior  2017    5   22  Primavera     32.0      10.0
#
#       edad  Posicion
# 44      26         G
# 45      26         G
# 46      26         G
# 47      26         G
# 48      26         G
# ...    ...       ...
# 817     35         F
# 852     36         G
# 927     36         G
# 928     36         G
# 1176    39         F
#
# [397 rows x 59 columns]

# %%
df_manu.loc[df_manu["minutos"].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, GAME_ID, TEAM_ID, TEAM_ABBREVIATION, TEAM_CITY, PLAYER_ID, PLAYER_NAME, NICKNAME, START_POSITION, COMMENT, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TO, PF, PTS, PLUS_MINUS, GAME_DATE_EST, GAME_STATUS_TEXT, HOME_TEAM_ID, VISITOR_TEAM_ID, SEASON, TEAM_ID_home, PTS_home, FG_PCT_home, FT_PCT_home, FG3_PCT_home, AST_home, REB_home, TEAM_ID_away, PTS_away, FG_PCT_away, FT_PCT_away, FG3_PCT_away, AST_away, REB_away, HOME_TEAM_WINS, Etapa, año, mes, dia, Estacion, minutos, segundos, edad, Posicion]
# Index: []
#
# [0 rows x 59 columns]

# %%
#Creamos un dataframe para almacenar las estadisticas que queremos
df = pd.DataFrame()

# %%
#Calculamos los puntos por temporada
pts_x_temp = df_manu.groupby("SEASON")["PTS"].sum()

# %%
df["PTS_X_TEMP"] = df_manu.groupby("SEASON")["PTS"].sum()

# %%
df
# Out:
#         PTS_X_TEMP
# SEASON
# 2003        1117.0
# 2004        1688.0
# 2005        1277.0
# 2006        1614.0
# 2007        1818.0
# 2008         683.0
# 2009        1456.0
# 2010        1538.0
# 2011         662.0
# 2012         973.0
# 2013        1215.0
# 2014         813.0
# 2015         666.0
# 2016         647.0
# 2017         636.0

# %%
#Calculamos los partidos por temporada, usando la columna Posicion que contiene datos los partidos jugados ya sea como titular o suplente
partidos_jugados = df_manu.loc[df_manu["Posicion"] != "No Jugo"]
partidos_jugados = partidos_jugados.groupby(["SEASON"])["GAME_ID"].count()
partidos_jugados
# Out:
# SEASON
# 2003     87
# 2004    100
# 2005     85
# 2006     99
# 2007     95
# 2008     44
# 2009     89
# 2010     90
# 2011     50
# 2012     84
# 2013     95
# 2014     81
# 2015     73
# 2016     89
# 2017     74
# Name: GAME_ID, dtype: int64

# %%
df["GAMES_X_TEMP"] = partidos_jugados

# %%
df
# Out:
#         PTS_X_TEMP  GAMES_X_TEMP
# SEASON
# 2003        1117.0            87
# 2004        1688.0           100
# 2005        1277.0            85
# 2006        1614.0            99
# 2007        1818.0            95
# 2008         683.0            44
# 2009        1456.0            89
# 2010        1538.0            90
# 2011         662.0            50
# 2012         973.0            84
# 2013        1215.0            95
# 2014         813.0            81
# 2015         666.0            73
# 2016         647.0            89
# 2017         636.0            74

# %%
#Calculamos el promedio de puntos por partido por temporada
promedio_pts_x_temp = df_manu.groupby("SEASON")["PTS"].sum() / partidos_jugados

# %%
df["PROM_PTS_X_TEMP"] = promedio_pts_x_temp.round(2)

# %%
df
# Out:
#         PTS_X_TEMP  GAMES_X_TEMP  PROM_PTS_X_TEMP
# SEASON
# 2003        1117.0            87            12.84
# 2004        1688.0           100            16.88
# 2005        1277.0            85            15.02
# 2006        1614.0            99            16.30
# 2007        1818.0            95            19.14
# 2008         683.0            44            15.52
# 2009        1456.0            89            16.36
# 2010        1538.0            90            17.09
# 2011         662.0            50            13.24
# 2012         973.0            84            11.58
# 2013        1215.0            95            12.79
# 2014         813.0            81            10.04
# 2015         666.0            73             9.12
# 2016         647.0            89             7.27
# 2017         636.0            74             8.59

# %%
#Calculamos los minutos jugados por cada temporada, solo usando la columna minutos
min_x_temp = df_manu.groupby("SEASON")["minutos"].sum()

#Calculamos los segundos jugados por temporada, usando la columna segundos 
segundos_x_temp = df_manu.groupby("SEASON")["segundos"].sum()

#Calculamos los minutos mas los segundos jugados por temporada
minutos_x_temp = df_manu.groupby("SEASON")["minutos"].sum() + (df_manu.groupby("SEASON")["segundos"].sum() / 60)

# %%
df["MIN_X_TEMP"] = minutos_x_temp.round(2)

# %%
df
# Out:
#         PTS_X_TEMP  GAMES_X_TEMP  PROM_PTS_X_TEMP  MIN_X_TEMP
# SEASON
# 2003        1117.0            87            12.84     2533.90
# 2004        1688.0           100            16.88     2992.30
# 2005        1277.0            85            15.02     2387.13
# 2006        1614.0            99            16.30     2737.65
# 2007        1818.0            95            19.14     2955.90
# 2008         683.0            44            15.52     1180.73
# 2009        1456.0            89            16.36     2579.33
# 2010        1538.0            90            17.09     2696.85
# 2011         662.0            50            13.24     1227.33
# 2012         973.0            84            11.58     2008.52
# 2013        1215.0            95            12.79     2206.70
# 2014         813.0            81            10.04     1798.78
# 2015         666.0            73             9.12     1404.38
# 2016         647.0            89             7.27     1633.78
# 2017         636.0            74             8.59     1468.35

# %%
#Calculamos los minutos por partido por temporada jugados
promedio_min_x_temp = (df_manu.groupby("SEASON")["minutos"].sum() + (df_manu.groupby("SEASON")["segundos"].sum() / 60)
)  / partidos_jugados

# %%
df["PROM_MIN_X_TEMP"] = promedio_min_x_temp.round(2)

# %%
df
# Out:
#         PTS_X_TEMP  GAMES_X_TEMP  PROM_PTS_X_TEMP  MIN_X_TEMP  PROM_MIN_X_TEMP
# SEASON
# 2003        1117.0            87            12.84     2533.90            29.13
# 2004        1688.0           100            16.88     2992.30            29.92
# 2005        1277.0            85            15.02     2387.13            28.08
# 2006        1614.0            99            16.30     2737.65            27.65
# 2007        1818.0            95            19.14     2955.90            31.11
# 2008         683.0            44            15.52     1180.73            26.83
# 2009        1456.0            89            16.36     2579.33            28.98
# 2010        1538.0            90            17.09     2696.85            29.96
# 2011         662.0            50            13.24     1227.33            24.55
# 2012         973.0            84            11.58     2008.52            23.91
# 2013        1215.0            95            12.79     2206.70            23.23
# 2014         813.0            81            10.04     1798.78            22.21
# 2015         666.0            73             9.12     1404.38            19.24
# 2016         647.0            89             7.27     1633.78            18.36
# 2017         636.0            74             8.59     1468.35            19.84

# %%
prom_pts_x_min_x_temp = df_manu.groupby("SEASON")["PTS"].sum() / (df_manu.groupby("SEASON")["minutos"].sum() + (df_manu.groupby("SEASON")["segundos"].sum() / 60))

# %%
df["PROM_PTS_X_MIN_X_TEMP"] = prom_pts_x_min_x_temp.round(2)

# %%
df
# Out:
#         PTS_X_TEMP  GAMES_X_TEMP  PROM_PTS_X_TEMP  MIN_X_TEMP  \
# SEASON
# 2003        1117.0            87            12.84     2533.90
# 2004        1688.0           100            16.88     2992.30
# 2005        1277.0            85            15.02     2387.13
# 2006        1614.0            99            16.30     2737.65
# 2007        1818.0            95            19.14     2955.90
# 2008         683.0            44            15.52     1180.73
# 2009        1456.0            89            16.36     2579.33
# 2010        1538.0            90            17.09     2696.85
# 2011         662.0            50            13.24     1227.33
# 2012         973.0            84            11.58     2008.52
# 2013        1215.0            95            12.79     2206.70
# 2014         813.0            81            10.04     1798.78
# 2015         666.0            73             9.12     1404.38
# 2016         647.0            89             7.27     1633.78
# 2017         636.0            74             8.59     1468.35
#
#         PROM_MIN_X_TEMP  PROM_PTS_X_MIN_X_TEMP
# SEASON
# 2003              29.13                   0.44
# 2004              29.92                   0.56
# 2005              28.08                   0.53
# 2006              27.65                   0.59
# 2007              31.11                   0.62
# 2008              26.83                   0.58
# 2009              28.98                   0.56
# 2010              29.96                   0.57
# 2011              24.55                   0.54
# 2012              23.91                   0.48
# 2013              23.23                   0.55
# 2014              22.21                   0.45
# 2015              19.24                   0.47
# 2016              18.36                   0.40
# 2017              19.84                   0.43

# %%
#Calculamos los partidos jugados de titular
part_titular = df_manu.groupby("SEASON")["START_POSITION"].count()

# %%
df["PART_TITULAR"] = part_titular

# %%
df
# Out:
#         PTS_X_TEMP  GAMES_X_TEMP  PROM_PTS_X_TEMP  MIN_X_TEMP  \
# SEASON
# 2003        1117.0            87            12.84     2533.90
# 2004        1688.0           100            16.88     2992.30
# 2005        1277.0            85            15.02     2387.13
# 2006        1614.0            99            16.30     2737.65
# 2007        1818.0            95            19.14     2955.90
# 2008         683.0            44            15.52     1180.73
# 2009        1456.0            89            16.36     2579.33
# 2010        1538.0            90            17.09     2696.85
# 2011         662.0            50            13.24     1227.33
# 2012         973.0            84            11.58     2008.52
# 2013        1215.0            95            12.79     2206.70
# 2014         813.0            81            10.04     1798.78
# 2015         666.0            73             9.12     1404.38
# 2016         647.0            89             7.27     1633.78
# 2017         636.0            74             8.59     1468.35
#
#         PROM_MIN_X_TEMP  PROM_PTS_X_MIN_X_TEMP  PART_TITULAR
# SEASON
# 2003              29.13                   0.44            38
# 2004              29.92                   0.56            89
# 2005              28.08                   0.53            67
# 2006              27.65                   0.59            36
# 2007              31.11                   0.62            29
# 2008              26.83                   0.58             7
# 2009              28.98                   0.56            31
# 2010              29.96                   0.57            84
# 2011              24.55                   0.54             9
# 2012              23.91                   0.48             3
# 2013              23.23                   0.55             3
# 2014              22.21                   0.45             0
# 2015              19.24                   0.47             0
# 2016              18.36                   0.40             1
# 2017              19.84                   0.43             0

# %%
df_manu
# Out:
#        index   GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0     249058  20300689  1610612759               SAS  San Antonio       1938
# 1     241187  20301020  1610612759               SAS  San Antonio       1938
# 2     241652  20301001  1610612759               SAS  San Antonio       1938
# 3     241985  20300985  1610612759               SAS  San Antonio       1938
# 4     242426  20300965  1610612759               SAS  San Antonio       1938
# ...      ...       ...         ...               ...          ...        ...
# 1287  432808  21700323  1610612759               SAS  San Antonio       1938
# 1288  433225  21700311  1610612759               SAS  San Antonio       1938
# 1289  433530  21700295  1610612759               SAS  San Antonio       1938
# 1290  434622  21700250  1610612759               SAS  San Antonio       1938
# 1291  433672  21700277  1610612759               SAS  San Antonio       1938
#
#         PLAYER_NAME NICKNAME START_POSITION COMMENT  ... HOME_TEAM_WINS  \
# 0     Manu Ginobili      NaN            NaN     NaN  ...              0
# 1     Manu Ginobili      NaN            NaN     NaN  ...              1
# 2     Manu Ginobili      NaN            NaN     NaN  ...              1
# 3     Manu Ginobili      NaN            NaN     NaN  ...              1
# 4     Manu Ginobili      NaN            NaN     NaN  ...              1
# ...             ...      ...            ...     ...  ...            ...
# 1287  Manu Ginobili      NaN            NaN     NaN  ...              0
# 1288  Manu Ginobili      NaN            NaN     NaN  ...              1
# 1289  Manu Ginobili      NaN            NaN     NaN  ...              1
# 1290  Manu Ginobili      NaN            NaN     NaN  ...              1
# 1291  Manu Ginobili      NaN            NaN     NaN  ...              0
#
#                      Etapa   año  mes  dia   Estacion  minutos  segundos  \
# 0            2003 - Rookie  2004    2   02   Invierno     24.0      50.0
# 1            2003 - Rookie  2004    3   23  Primavera     20.0      45.0
# 2            2003 - Rookie  2004    3   20  Primavera     23.0      38.0
# 3            2003 - Rookie  2004    3   18  Primavera     28.0       2.0
# 4            2003 - Rookie  2004    3   15  Primavera     24.0      38.0
# ...                    ...   ...  ...  ...        ...      ...       ...
# 1287  2013 a 2017 - Senior  2017   12   01   Invierno     24.0      37.0
# 1288  2013 a 2017 - Senior  2017   11   29      Otoño     23.0      35.0
# 1289  2013 a 2017 - Senior  2017   11   27      Otoño     16.0      55.0
# 1290  2013 a 2017 - Senior  2017   11   20      Otoño     25.0      38.0
# 1291  2013 a 2017 - Senior  2017   11   25      Otoño     19.0      58.0
#
#       edad  Posicion
# 0       26  Suplente
# 1       26  Suplente
# 2       26  Suplente
# 3       26  Suplente
# 4       26  Suplente
# ...    ...       ...
# 1287    40  Suplente
# 1288    40  Suplente
# 1289    40  Suplente
# 1290    40  Suplente
# 1291    40  Suplente
#
# [1292 rows x 59 columns]

# %%
#Calculamos el porcentaje de partidos jugados de titular
porc_part_titular = (df_manu.groupby("SEASON")["START_POSITION"].count() * 100) / partidos_jugados
porc_part_titular
# Out:
# SEASON
# 2003    43.678161
# 2004    89.000000
# 2005    78.823529
# 2006    36.363636
# 2007    30.526316
# 2008    15.909091
# 2009    34.831461
# 2010    93.333333
# 2011    18.000000
# 2012     3.571429
# 2013     3.157895
# 2014     0.000000
# 2015     0.000000
# 2016     1.123596
# 2017     0.000000
# dtype: float64

# %%
df["PORC_PART_TITULAR"] = porc_part_titular.round(2)

# %%
df
# Out:
#         PTS_X_TEMP  GAMES_X_TEMP  PROM_PTS_X_TEMP  MIN_X_TEMP  \
# SEASON
# 2003        1117.0            87            12.84     2533.90
# 2004        1688.0           100            16.88     2992.30
# 2005        1277.0            85            15.02     2387.13
# 2006        1614.0            99            16.30     2737.65
# 2007        1818.0            95            19.14     2955.90
# 2008         683.0            44            15.52     1180.73
# 2009        1456.0            89            16.36     2579.33
# 2010        1538.0            90            17.09     2696.85
# 2011         662.0            50            13.24     1227.33
# 2012         973.0            84            11.58     2008.52
# 2013        1215.0            95            12.79     2206.70
# 2014         813.0            81            10.04     1798.78
# 2015         666.0            73             9.12     1404.38
# 2016         647.0            89             7.27     1633.78
# 2017         636.0            74             8.59     1468.35
#
#         PROM_MIN_X_TEMP  PROM_PTS_X_MIN_X_TEMP  PART_TITULAR  \
# SEASON
# 2003              29.13                   0.44            38
# 2004              29.92                   0.56            89
# 2005              28.08                   0.53            67
# 2006              27.65                   0.59            36
# 2007              31.11                   0.62            29
# 2008              26.83                   0.58             7
# 2009              28.98                   0.56            31
# 2010              29.96                   0.57            84
# 2011              24.55                   0.54             9
# 2012              23.91                   0.48             3
# 2013              23.23                   0.55             3
# 2014              22.21                   0.45             0
# 2015              19.24                   0.47             0
# 2016              18.36                   0.40             1
# 2017              19.84                   0.43             0
#
#         PORC_PART_TITULAR
# SEASON
# 2003                43.68
# 2004                89.00
# 2005                78.82
# 2006                36.36
# 2007                30.53
# 2008                15.91
# 2009                34.83
# 2010                93.33
# 2011                18.00
# 2012                 3.57
# 2013                 3.16
# 2014                 0.00
# 2015                 0.00
# 2016                 1.12
# 2017                 0.00

# %%
promedio_reb_x_temp = df_manu.groupby("SEASON")["REB"].sum() / partidos_jugados
promedio_ast_x_temp = df_manu.groupby("SEASON")["AST"].sum() / partidos_jugados
promedio_blk_x_temp = df_manu.groupby("SEASON")["BLK"].sum() / partidos_jugados
promedio_stl_x_temp = df_manu.groupby("SEASON")["STL"].sum() / partidos_jugados
promedio_to_x_temp = df_manu.groupby("SEASON")["TO"].sum() / partidos_jugados

# %%
df["PROM_REB_X_TEMP"] = promedio_reb_x_temp.round(2)
df["PROM_AST_X_TEMP"] = promedio_ast_x_temp.round(2)
df["PROM_TAPAS_X_TEMP"] = promedio_blk_x_temp.round(2)
df["PROM_ROBOS_X_TEMP"] = promedio_stl_x_temp.round(2)
df["PROM_PERD_X_TEMP"] = promedio_to_x_temp.round(2)

# %%
df = df.reset_index()

# %%
df
# Out:
#     SEASON  PTS_X_TEMP  GAMES_X_TEMP  PROM_PTS_X_TEMP  MIN_X_TEMP  \
# 0     2003      1117.0            87            12.84     2533.90
# 1     2004      1688.0           100            16.88     2992.30
# 2     2005      1277.0            85            15.02     2387.13
# 3     2006      1614.0            99            16.30     2737.65
# 4     2007      1818.0            95            19.14     2955.90
# 5     2008       683.0            44            15.52     1180.73
# 6     2009      1456.0            89            16.36     2579.33
# 7     2010      1538.0            90            17.09     2696.85
# 8     2011       662.0            50            13.24     1227.33
# 9     2012       973.0            84            11.58     2008.52
# 10    2013      1215.0            95            12.79     2206.70
# 11    2014       813.0            81            10.04     1798.78
# 12    2015       666.0            73             9.12     1404.38
# 13    2016       647.0            89             7.27     1633.78
# 14    2017       636.0            74             8.59     1468.35
#
#     PROM_MIN_X_TEMP  PROM_PTS_X_MIN_X_TEMP  PART_TITULAR  PORC_PART_TITULAR  \
# 0             29.13                   0.44            38              43.68
# 1             29.92                   0.56            89              89.00
# 2             28.08                   0.53            67              78.82
# 3             27.65                   0.59            36              36.36
# 4             31.11                   0.62            29              30.53
# 5             26.83                   0.58             7              15.91
# 6             28.98                   0.56            31              34.83
# 7             29.96                   0.57            84              93.33
# 8             24.55                   0.54             9              18.00
# 9             23.91                   0.48             3               3.57
# 10            23.23                   0.55             3               3.16
# 11            22.21                   0.45             0               0.00
# 12            19.24                   0.47             0               0.00
# 13            18.36                   0.40             1               1.12
# 14            19.84                   0.43             0               0.00
#
#     PROM_REB_X_TEMP  PROM_AST_X_TEMP  PROM_TAPAS_X_TEMP  PROM_ROBOS_X_TEMP  \
# 0              4.56             3.70               0.20               1.76
# 1              4.76             3.99               0.34               1.55
# 2              3.65             3.42               0.44               1.48
# 3              4.49             3.49               0.31               1.44
# 4              4.54             4.38               0.41               1.27
# 5              4.50             3.57               0.36               1.45
# 6              3.71             4.96               0.29               1.48
# 7              3.62             4.81               0.36               1.54
# 8              3.40             4.22               0.32               0.72
# 9              3.43             4.61               0.24               1.26
# 10             3.02             4.26               0.23               1.15
# 11             3.10             4.19               0.35               0.89
# 12             2.49             2.99               0.22               1.12
# 13             2.33             2.57               0.21               1.15
# 14             2.32             2.59               0.23               0.74
#
#     PROM_PERD_X_TEMP
# 0               2.09
# 1               2.45
# 2               2.02
# 3               2.07
# 4               2.71
# 5               2.00
# 6               2.12
# 7               2.20
# 8               2.22
# 9               2.33
# 10              2.11
# 11              2.25
# 12              1.53
# 13              1.28
# 14              1.64

# %%
#Dejamos el DF de SAS unicamente con las temporadas en las que jugo Manu para comparar su influencia en los partidos que jugo y los que no.
df_SAS_con_manu = df_SAS.loc[df_SAS["SEASON"] < 2018]

# %%
df_SAS_con_manu
# Out:
#       GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 2431     2014-06-15  41300405    1610612759       1610612748    2013
# 2432     2014-06-12  41300404    1610612748       1610612759    2013
# 2433     2014-06-10  41300403    1610612748       1610612759    2013
# 2434     2014-06-08  41300402    1610612759       1610612748    2013
# 2435     2014-06-05  41300401    1610612759       1610612748    2013
# ...             ...       ...           ...              ...     ...
# 24921    2014-10-24  11400113    1610612745       1610612759    2014
# 24934    2014-10-22  11400105    1610612759       1610612737    2014
# 24949    2014-10-20  11400091    1610612759       1610612758    2014
# 24958    2014-10-18  11400078    1610612759       1610612748    2014
# 24971    2014-10-16  11400062    1610612756       1610612759    2014
#
#        HOME_TEAM_WINS
# 2431                1
# 2432                0
# 2433                0
# 2434                0
# 2435                1
# ...               ...
# 24921               1
# 24934               0
# 24949               1
# 24958               0
# 24971               1
#
# [1498 rows x 6 columns]

# %%
df_SAS
# Out:
#       GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 13       2021-11-16  22100212    1610612746       1610612759    2021
# 25       2021-11-14  22100192    1610612747       1610612759    2021
# 46       2021-11-12  22100181    1610612759       1610612742    2021
# 61       2021-11-10  22100166    1610612759       1610612758    2021
# 82       2021-11-07  22100144    1610612760       1610612759    2021
# ...             ...       ...           ...              ...     ...
# 24921    2014-10-24  11400113    1610612745       1610612759    2014
# 24934    2014-10-22  11400105    1610612759       1610612737    2014
# 24949    2014-10-20  11400091    1610612759       1610612758    2014
# 24958    2014-10-18  11400078    1610612759       1610612748    2014
# 24971    2014-10-16  11400062    1610612756       1610612759    2014
#
#        HOME_TEAM_WINS
# 13                  1
# 25                  1
# 46                  0
# 61                  1
# 82                  1
# ...               ...
# 24921               1
# 24934               0
# 24949               1
# 24958               0
# 24971               1
#
# [1769 rows x 6 columns]

# %%
#Creamos un Dataset con las estadisticas de SAS en las temporadas que jugo Manu.
df_estad_SAS = pd.DataFrame()

# %%
df_estad_SAS["PART_JUGADOS"] = df_SAS_con_manu.groupby("SEASON")["GAME_ID"].count()

# %%
df_estad_SAS
# Out:
#         PART_JUGADOS
# SEASON
# 2003             100
# 2004             108
# 2005             103
# 2006             107
# 2007             104
# 2008              94
# 2009              98
# 2010              94
# 2011              82
# 2012             109
# 2013             111
# 2014              94
# 2015              98
# 2016             104
# 2017              92

# %%
partidos_ganados_local = df_SAS_con_manu.loc[(df_SAS_con_manu["HOME_TEAM_ID"] == 1610612759) & (df_SAS_con_manu["HOME_TEAM_WINS"] == 1)].groupby("SEASON")["GAME_ID"].count()

# %%
df_estad_SAS["PART_GAN_LOCAL"] = partidos_ganados_local

# %%
df_estad_SAS
# Out:
#         PART_JUGADOS  PART_GAN_LOCAL
# SEASON
# 2003             100              37
# 2004             108              49
# 2005             103              39
# 2006             107              42
# 2007             104              43
# 2008              94              30
# 2009              98              33
# 2010              94              40
# 2011              82              35
# 2012             109              45
# 2013             111              44
# 2014              94              35
# 2015              98              45
# 2016             104              38
# 2017              92              36

# %%
partidos_ganados_vis = df_SAS_con_manu.loc[(df_SAS_con_manu["VISITOR_TEAM_ID"] == 1610612759) & (arc_games_copia["HOME_TEAM_WINS"] == 0)].groupby("SEASON")["GAME_ID"].count()

# %%
df_estad_SAS["PART_GAN_VIS"] = partidos_ganados_vis

# %%
df_estad_SAS
# Out:
#         PART_JUGADOS  PART_GAN_LOCAL  PART_GAN_VIS
# SEASON
# 2003             100              37            29
# 2004             108              49            29
# 2005             103              39            32
# 2006             107              42            34
# 2007             104              43            25
# 2008              94              30            28
# 2009              98              33            24
# 2010              94              40            26
# 2011              82              35            26
# 2012             109              45            31
# 2013             111              44            36
# 2014              94              35            24
# 2015              98              45            30
# 2016             104              38            35
# 2017              92              36            15

# %%
partidos_perdidos_local = df_SAS_con_manu.loc[(df_SAS_con_manu["HOME_TEAM_ID"] == 1610612759) & (df_SAS_con_manu["HOME_TEAM_WINS"] == 0)].groupby("SEASON")["GAME_ID"].count()
partidos_perdidos_vis = df_SAS_con_manu.loc[(df_SAS_con_manu["VISITOR_TEAM_ID"] == 1610612759) & (df_SAS_con_manu["HOME_TEAM_WINS"] == 1)].groupby("SEASON")["GAME_ID"].count()

# %%
df_estad_SAS["PART_PER_LOC"] = partidos_perdidos_local
df_estad_SAS["PART_PER_VIS"] = partidos_perdidos_vis

# %%
df_estad_SAS
# Out:
#         PART_JUGADOS  PART_GAN_LOCAL  PART_GAN_VIS  PART_PER_LOC  PART_PER_VIS
# SEASON
# 2003             100              37            29            14            20
# 2004             108              49            29             6            24
# 2005             103              39            32            13            19
# 2006             107              42            34            14            17
# 2007             104              43            25             8            28
# 2008              94              30            28            18            18
# 2009              98              33            24            16            25
# 2010              94              40            26             7            21
# 2011              82              35            26             6            15
# 2012             109              45            31             9            24
# 2013             111              44            36            13            18
# 2014              94              35            24            12            23
# 2015              98              45            30             4            19
# 2016             104              38            35            14            17
# 2017              92              36            15            10            31

# %%
#Creamos el DataSet con los partidos que Manu jugo
df_SAS_con_Manu = pd.DataFrame()

# %%
df_SAS_con_Manu["PART_JUGADOS"] = partidos_jugados
df_SAS_con_Manu["PART_GAN_LOCAL"] = df_manu.loc[(df_manu["HOME_TEAM_ID"] == 1610612759) & (df_manu["HOME_TEAM_WINS"] == 1)].groupby("SEASON")["PTS"].count()
df_SAS_con_Manu["PART_GAN_VIS"] = df_manu.loc[(df_manu["VISITOR_TEAM_ID"] == 1610612759) & (df_manu["HOME_TEAM_WINS"] == 0)].groupby("SEASON")["PTS"].count()
df_SAS_con_Manu["PART_PER_LOC"] = df_manu.loc[(df_manu["HOME_TEAM_ID"] == 1610612759) & (df_manu["HOME_TEAM_WINS"] == 0)].groupby("SEASON")["PTS"].count()
df_SAS_con_Manu["PART_PER_VIS"] = df_manu.loc[(df_manu["VISITOR_TEAM_ID"] == 1610612759) & (df_manu["HOME_TEAM_WINS"] == 1)].groupby("SEASON")["PTS"].count()

# %%
df_SAS_con_Manu
# Out:
#         PART_JUGADOS  PART_GAN_LOCAL  PART_GAN_VIS  PART_PER_LOC  PART_PER_VIS
# SEASON
# 2003              87              35            24             9            19
# 2004             100              45            27             5            23
# 2005              85              32            27            11            15
# 2006              99              41            33            12            13
# 2007              95              38            24             7            26
# 2008              44              16            16             4             8
# 2009              89              29            22            15            23
# 2010              90              40            26             5            19
# 2011              50              24            15             4             7
# 2012              84              36            25             7            16
# 2013              95              40            30            11            14
# 2014              81              31            20            12            18
# 2015              73              39            16             4            14
# 2016              89              33            29            13            14
# 2017              74              32            10             8            24

# %% [markdown]
# ## 4. Presentación de los Datos <a id="presentacion"></a>

# %% [markdown]
# Comenzaremos a responder las preguntas planteadas como objetivos del proyecto:
#
# #### 1 - Cuál fue el promedio de puntos por partidos y por minutos jugados de Emanuel Ginobili durante su carrera en la NBA? Como se distribuyo durante sus diferentes temporadas?

# %%
sty.available
sty.use("seaborn-pastel")

# %%
df
# Out:
#     SEASON  PTS_X_TEMP  GAMES_X_TEMP  PROM_PTS_X_TEMP  MIN_X_TEMP  \
# 0     2003      1117.0            87            12.84     2533.90
# 1     2004      1688.0           100            16.88     2992.30
# 2     2005      1277.0            85            15.02     2387.13
# 3     2006      1614.0            99            16.30     2737.65
# 4     2007      1818.0            95            19.14     2955.90
# 5     2008       683.0            44            15.52     1180.73
# 6     2009      1456.0            89            16.36     2579.33
# 7     2010      1538.0            90            17.09     2696.85
# 8     2011       662.0            50            13.24     1227.33
# 9     2012       973.0            84            11.58     2008.52
# 10    2013      1215.0            95            12.79     2206.70
# 11    2014       813.0            81            10.04     1798.78
# 12    2015       666.0            73             9.12     1404.38
# 13    2016       647.0            89             7.27     1633.78
# 14    2017       636.0            74             8.59     1468.35
#
#     PROM_MIN_X_TEMP  PROM_PTS_X_MIN_X_TEMP  PART_TITULAR  PORC_PART_TITULAR  \
# 0             29.13                   0.44            38              43.68
# 1             29.92                   0.56            89              89.00
# 2             28.08                   0.53            67              78.82
# 3             27.65                   0.59            36              36.36
# 4             31.11                   0.62            29              30.53
# 5             26.83                   0.58             7              15.91
# 6             28.98                   0.56            31              34.83
# 7             29.96                   0.57            84              93.33
# 8             24.55                   0.54             9              18.00
# 9             23.91                   0.48             3               3.57
# 10            23.23                   0.55             3               3.16
# 11            22.21                   0.45             0               0.00
# 12            19.24                   0.47             0               0.00
# 13            18.36                   0.40             1               1.12
# 14            19.84                   0.43             0               0.00
#
#     PROM_REB_X_TEMP  PROM_AST_X_TEMP  PROM_TAPAS_X_TEMP  PROM_ROBOS_X_TEMP  \
# 0              4.56             3.70               0.20               1.76
# 1              4.76             3.99               0.34               1.55
# 2              3.65             3.42               0.44               1.48
# 3              4.49             3.49               0.31               1.44
# 4              4.54             4.38               0.41               1.27
# 5              4.50             3.57               0.36               1.45
# 6              3.71             4.96               0.29               1.48
# 7              3.62             4.81               0.36               1.54
# 8              3.40             4.22               0.32               0.72
# 9              3.43             4.61               0.24               1.26
# 10             3.02             4.26               0.23               1.15
# 11             3.10             4.19               0.35               0.89
# 12             2.49             2.99               0.22               1.12
# 13             2.33             2.57               0.21               1.15
# 14             2.32             2.59               0.23               0.74
#
#     PROM_PERD_X_TEMP
# 0               2.09
# 1               2.45
# 2               2.02
# 3               2.07
# 4               2.71
# 5               2.00
# 6               2.12
# 7               2.20
# 8               2.22
# 9               2.33
# 10              2.11
# 11              2.25
# 12              1.53
# 13              1.28
# 14              1.64

# %%
df[["SEASON", "PROM_PTS_X_TEMP"]]
# Out:
#     SEASON  PROM_PTS_X_TEMP
# 0     2003            12.84
# 1     2004            16.88
# 2     2005            15.02
# 3     2006            16.30
# 4     2007            19.14
# 5     2008            15.52
# 6     2009            16.36
# 7     2010            17.09
# 8     2011            13.24
# 9     2012            11.58
# 10    2013            12.79
# 11    2014            10.04
# 12    2015             9.12
# 13    2016             7.27
# 14    2017             8.59

# %%
pregunta1a = df.groupby(["SEASON"])["PROM_PTS_X_TEMP"].sum()
pregunta1a = pregunta1a.plot(legend = False, figsize = (10,5))
plt.title("Promedio de puntos por temporada",fontdict = {'fontsize':20})
plt.ylabel('Promedio de Puntos', fontdict = {'fontsize':20})
plt.ticklabel_format(useOffset = False)
plt.xticks(rotation=50)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Temporada', fontdict = {'fontsize':20});

# %%
pregunta1b = df.groupby(["SEASON"])["PROM_PTS_X_MIN_X_TEMP"].sum()
pregunta1b = pregunta1b.plot(legend = False, figsize = (10,5))
plt.title("Promedio de puntos por minuto por temporada", fontdict = {'fontsize':20})
plt.ylabel('Promedio de puntos por minuto', fontdict = {'fontsize':20})
plt.xticks(rotation=50)
plt.ticklabel_format(useOffset = False)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Temporada', fontdict = {'fontsize':20});

# %%
pregunta1c = df_manu.groupby("Etapa")["PTS"].sum() / df_manu.groupby("Etapa")["PTS"].count()
pregunta1c = pregunta1c.plot.bar(figsize = (10,7))
plt.title("Promedio de puntos por etapas", fontdict = {'fontsize':20})
plt.ylabel('Promedio de Puntos', fontdict = {'fontsize':20})
plt.xticks(rotation=50)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Etapas',fontdict = {'fontsize':20});

# %%
pregunta1d = df_manu.groupby("edad")["PTS"].sum() / df_manu.groupby("edad")["PTS"].count()
pregunta1d = pregunta1d.plot.bar(figsize = (10,7))
plt.title("Promedio de puntos por edad", fontdict = {'fontsize':20})
plt.ylabel('Promedio de Puntos', fontdict = {'fontsize':20})
plt.xticks(rotation=50)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Edad', fontdict = {'fontsize':20});

# %% [markdown]
# #### 2. Cúal fue el promedio de minutos jugados durante su carrera en la NBA? Como se distribuyo durante sus diferentes temporadas?

# %%
df["PROM_MIN_X_TEMP"]
# Out:
# 0     29.13
# 1     29.92
# 2     28.08
# 3     27.65
# 4     31.11
# 5     26.83
# 6     28.98
# 7     29.96
# 8     24.55
# 9     23.91
# 10    23.23
# 11    22.21
# 12    19.24
# 13    18.36
# 14    19.84
# Name: PROM_MIN_X_TEMP, dtype: float64

# %%
pregunta2 = df.groupby(["SEASON"])["PROM_MIN_X_TEMP"].sum()
pregunta2 = pregunta2.plot.bar(figsize =(10,8))
plt.title('Promedio de minutos jugados por temporada', fontdict = {'fontsize':20})
plt.ylabel('Promedio de Minutos', fontdict = {'fontsize':20})
plt.xlabel('Temporada', fontdict = {'fontsize':20})
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# %% [markdown]
# #### 3. Cuál fue el porcentaje de partidos de titular que jugo? Fue variando en los distintos años?

# %%
df["PORC_PART_TITULAR"]
# Out:
# 0     43.68
# 1     89.00
# 2     78.82
# 3     36.36
# 4     30.53
# 5     15.91
# 6     34.83
# 7     93.33
# 8     18.00
# 9      3.57
# 10     3.16
# 11     0.00
# 12     0.00
# 13     1.12
# 14     0.00
# Name: PORC_PART_TITULAR, dtype: float64

# %%
pregunta3a = df.groupby(["SEASON"])["PORC_PART_TITULAR"].sum()
pregunta3a = pregunta3a.to_frame().reset_index()
pregunta3a
# Out:
#     SEASON  PORC_PART_TITULAR
# 0     2003              43.68
# 1     2004              89.00
# 2     2005              78.82
# 3     2006              36.36
# 4     2007              30.53
# 5     2008              15.91
# 6     2009              34.83
# 7     2010              93.33
# 8     2011              18.00
# 9     2012               3.57
# 10    2013               3.16
# 11    2014               0.00
# 12    2015               0.00
# 13    2016               1.12
# 14    2017               0.00

# %%
pregunta3a = df.groupby(["SEASON"])["PORC_PART_TITULAR"].sum()
pregunta3a = pregunta3a.to_frame().reset_index()
pregunta3a = pregunta3a.plot(kind='scatter', x='SEASON', y ='PORC_PART_TITULAR', color='violet',figsize=(10,5))
plt.title("Evolucion de los partidos jugados de titular por temporada", fontdict = {'fontsize':20})
plt.ticklabel_format(useOffset = False)
plt.xlabel("Temporada", fontdict = {'fontsize':20})
plt.ylabel("Porcentaje", fontdict = {'fontsize':20});

# %% [markdown]
# Analizamos una temporada en especial, tomando la 2007, temporada en la cual fue elegido como el mejor sexto hombre.

# %%
partidos_jugados_2007 = df_manu.loc[df_manu["Posicion"] != "No Jugo"]
partidos_jugados_2007 = partidos_jugados_2007.groupby(["SEASON","Posicion"], as_index=False)["GAME_ID"].count()
partidos_jugados_2007 = partidos_jugados_2007.rename(columns = {'GAME_ID':'Cantidad Partidos'})
#partidos_jugados_2007 
pregunta3b = partidos_jugados_2007.loc[partidos_jugados_2007["SEASON"] == 2007]
pregunta3b = pregunta3b.reset_index()
pregunta3b
# Out:
#    index  SEASON  Posicion  Cantidad Partidos
# 0      9    2007         G                 29
# 1     10    2007  Suplente                 66

# %%
pregunta3b.plot.pie(x='Posicion', y='Cantidad Partidos',figsize=(10,10), autopct='%.2f%%', labels=None, fontsize=20)
plt.legend(['BASE', 'SUPLENTE'],loc='best', fontsize=10)
plt.xlabel("POSICION", fontdict = {'fontsize':20});
plt.ylabel("PORCENTAJE DE PARTIDOS", fontdict = {'fontsize':20})
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# %%
pregunta3d = pd.DataFrame()
pregunta3d["G"] = df_manu.loc[df_manu["Posicion"] == "G"].groupby("SEASON")["GAME_ID"].count()
pregunta3d["F"] = df_manu.loc[df_manu["Posicion"] == "F"].groupby("SEASON")["GAME_ID"].count()
pregunta3d["Suplente"] = df_manu.loc[df_manu["Posicion"] == "Suplente"].groupby("SEASON")["GAME_ID"].count()
pregunta3d["No Jugo"] = df_manu.loc[df_manu["Posicion"] == "No Jugo"].groupby("SEASON")["GAME_ID"].count()
pregunta3d = pregunta3d.reset_index()
pregunta3d.plot(x="SEASON", kind="bar", stacked=True, figsize=(10,10));

#df.plot(x='Team', kind='bar', stacked=True,
#        title='Stacked Bar Graph by dataframe')

# %%
df = pd.DataFrame([['A', 10, 20, 10, 26], ['B', 20, 25, 15, 21], ['C', 12, 15, 19, 6],
                   ['D', 10, 18, 11, 19]],
                  columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4'])
# view data
print(df)
  
# plot data in stack manner of bar type
#df.plot(x='Team', kind='bar', stacked=True,
#        title='Stacked Bar Graph by dataframe')
# Out:
#   Team  Round 1  Round 2  Round 3  Round 4
# 0    A       10       20       10       26
# 1    B       20       25       15       21
# 2    C       12       15       19        6
# 3    D       10       18       11       19

# %% [markdown]
# #### 4 - Como evolucionaron sus estadisticas en los distintos rubros durante toda su carrera?

# %%
fig, axis = plt.subplots(3, 2,figsize=(25, 20))
fig.suptitle('Evolucion de las estadisticas durante su carrera', fontsize=25)

# primer plot
puntos = df.groupby(["SEASON"])["PROM_PTS_X_TEMP"].sum()
axis[0, 0].plot(puntos, color = "green")
axis[0, 0].set_title("Puntos por temporada",fontdict = {'fontsize':20})
axis[0, 0].set_xlabel("Temporada",fontdict = {'fontsize':15})
axis[0, 0].set_ylabel("Puntos", fontdict = {'fontsize':15})  
axis[0, 0].ticklabel_format(useOffset = False)
axis[0, 0].tick_params(axis='both', which='major', labelsize=15);

# segundo plot
rebotes = df.groupby(["SEASON"])["PROM_REB_X_TEMP"].sum()
axis[0, 1].plot(rebotes, color ="red")
axis[0, 1].set_title("Rebotes por temporada", fontdict = {'fontsize':20})
axis[0, 1].set_xlabel("Temporada", fontdict = {'fontsize':15})
axis[0, 1].set_ylabel("Rebotes", fontdict = {'fontsize':15}) 
axis[0, 1].ticklabel_format(useOffset = False)
axis[0, 1].tick_params(axis='both', which='major', labelsize=15);

# tercer plot
asistencias = df.groupby(["SEASON"])["PROM_AST_X_TEMP"].sum()
axis[1, 0].plot(asistencias, color ="white")
axis[1, 0].set_title("Asistencias por temporada", fontdict = {'fontsize':20})
axis[1, 0].set_xlabel("Temporada", fontdict = {'fontsize':15})
axis[1, 0].set_ylabel("Asistencias", fontdict = {'fontsize':15})   
axis[1, 0].ticklabel_format(useOffset = False)
axis[1, 0].tick_params(axis='both', which='major', labelsize=15);

# cuarto plot
tapas = df.groupby(["SEASON"])["PROM_TAPAS_X_TEMP"].sum()
axis[1, 1].plot(tapas, color ="black")
axis[1, 1].set_title("Bloqueos por temporada", fontdict = {'fontsize':20})
axis[1, 1].set_xlabel("Temporada", fontdict = {'fontsize':15})
axis[1, 1].set_ylabel("Bloqueos", fontdict = {'fontsize':15})   
axis[1, 1].ticklabel_format(useOffset = False)
axis[1, 1].tick_params(axis='both', which='major', labelsize=15);


# quinto plot
robos = df.groupby(["SEASON"])["PROM_ROBOS_X_TEMP"].sum()
axis[2, 0].plot(robos, color = "violet")
axis[2, 0].set_title("Robos por temporada", fontdict = {'fontsize':20})
axis[2, 0].set_xlabel("Temporada", fontdict = {'fontsize':15})
axis[2, 0].set_ylabel("Robos", fontdict = {'fontsize':15})   
axis[2, 0].ticklabel_format(useOffset = False)
axis[2, 0].tick_params(axis='both', which='major', labelsize=15);
         
# sexto plot
perdidas =  df.groupby(["SEASON"])["PROM_PERD_X_TEMP"].sum()
axis[2, 1].plot(perdidas, color = "orange")
axis[2, 1].set_title("Perdidas por temporada", fontdict = {'fontsize':20});
axis[2, 1].set_xlabel("Temporada", fontdict = {'fontsize':15})
axis[2, 1].set_ylabel("Pberdidas", fontdict = {'fontsize':15})   
axis[2, 1].ticklabel_format(useOffset = False)
axis[2, 1].tick_params(axis='both', which='major', labelsize=15);

# combinamos y mostramos el grafico
plt.show()

# %%
df["PROM_PTS_X_TEMP"]
# Out:
# SEASON
# 2003    12.84
# 2004    16.88
# 2005    15.02
# 2006    16.30
# 2007    19.14
# 2008    15.52
# 2009    16.36
# 2010    17.09
# 2011    13.24
# 2012    11.58
# 2013    12.79
# 2014    10.04
# 2015     9.12
# 2016     7.27
# 2017     8.59
# Name: PROM_PTS_X_TEMP, dtype: float64

# %% [markdown]
# #### 5 - Como fueron los resultados del equipo con el en cancha o sin su presencia?

# %%
df_SAS_con_Manu
# Out:
#         PART_JUGADOS  PART_GAN_LOCAL  PART_GAN_VIS  PART_PER_LOC  PART_PER_VIS
# SEASON
# 2003              87              35            24             9            19
# 2004             100              45            27             5            23
# 2005              85              32            27            11            15
# 2006              99              41            33            12            13
# 2007              95              38            24             7            26
# 2008              44              16            16             4             8
# 2009              89              29            22            15            23
# 2010              90              40            26             5            19
# 2011              50              24            15             4             7
# 2012              84              36            25             7            16
# 2013              95              40            30            11            14
# 2014              81              31            20            12            18
# 2015              73              39            16             4            14
# 2016              89              33            29            13            14
# 2017              74              32            10             8            24

# %%
df_estad_SAS
# Out:
#         PART_JUGADOS  PART_GAN_LOCAL  PART_GAN_VIS  PART_PER_LOC  PART_PER_VIS
# SEASON
# 2003             100              37            29            14            20
# 2004             108              49            29             6            24
# 2005             103              39            32            13            19
# 2006             107              42            34            14            17
# 2007             104              43            25             8            28
# 2008              94              30            28            18            18
# 2009              98              33            24            16            25
# 2010              94              40            26             7            21
# 2011              82              35            26             6            15
# 2012             109              45            31             9            24
# 2013             111              44            36            13            18
# 2014              94              35            24            12            23
# 2015              98              45            30             4            19
# 2016             104              38            35            14            17
# 2017              92              36            15            10            31

# %%
dfprueba = df_SAS_con_Manu.reset_index()

# %%
dfprueba
# Out:
#     SEASON  PART_JUGADOS  PART_GAN_LOCAL  PART_GAN_VIS  PART_PER_LOC  \
# 0     2003            87              35            24             9
# 1     2004           100              45            27             5
# 2     2005            85              32            27            11
# 3     2006            99              41            33            12
# 4     2007            95              38            24             7
# 5     2008            44              16            16             4
# 6     2009            89              29            22            15
# 7     2010            90              40            26             5
# 8     2011            50              24            15             4
# 9     2012            84              36            25             7
# 10    2013            95              40            30            11
# 11    2014            81              31            20            12
# 12    2015            73              39            16             4
# 13    2016            89              33            29            13
# 14    2017            74              32            10             8
#
#     PART_PER_VIS
# 0             19
# 1             23
# 2             15
# 3             13
# 4             26
# 5              8
# 6             23
# 7             19
# 8              7
# 9             16
# 10            14
# 11            18
# 12            14
# 13            14
# 14            24

# %% [markdown]
# ### EXTRAS

# %% [markdown]
# #### Análisis Porcentaje de puntos por estación en toda su carrera

# %%
extras = df_manu.groupby(["Estacion"])["PTS"].sum()
extras = extras.to_frame().reset_index()
#extras = extras.loc[extras["SEASON"] == 2004]
extras.plot.pie(x='Estacion', y='PTS',figsize=(10,10), autopct='%.2f%%', labels=None)
plt.legend(['Invierno','Otoño', 'Primavera','Verano'],loc='best')
plt.xlabel("PORCENTAJE DE PUNTOS POR ESTACION");
plt.ylabel("PTS");

# %% [markdown]
# #### Análisis promedio de puntos por estación en toda su carrera

# %%
extras1 = df_manu.groupby(["Estacion"])["PTS"].sum() / df_manu.groupby(["Estacion"])["PTS"].count()
extras1
# Out:
# Estacion
# Invierno     13.947896
# Otoño        12.484127
# Primavera    13.711160
# Verano       15.962963
# Name: PTS, dtype: float64

# %% [markdown]
# #### Análisis de puntos por estación por temporada en toda su carrera

# %%
sty.use("seaborn-pastel")
sns.catplot(x="SEASON", hue = "Estacion", kind='count', data=df_manu, height=5, aspect=2, estimator=np.sum )
plt.xlabel("Temporada")
plt.ylabel("Cantidad de partidos")
plt.title("Cantidad de partidos por estacion por temporada");

# %%
sty.use("seaborn-pastel")
sns.catplot(x="SEASON", y = "PTS", hue = "Estacion", kind='bar', data=df_manu, height=5, aspect=2, estimator=np.average )
plt.xlabel("Temporada")
plt.ylabel("Promedio de puntos")
plt.title("Puntos por estacion por temporada")
plt.savefig("Promedio de puntos_por_estacion_por_temporada.jpg");

# %% [markdown]
# ## 5. Conclusiones <a id="conclusiones"></a>
#
# De acuerdo al análisis de datos, en primer lugar podemos observar la excelente carrera desarrollada por Emanuel Ginobili durante todos sus años en la NBA, sin descuidar que llego a la misma en el año 2003 ya con 26 años y se mantuvo compitiendo en el máximo nivel hasta los 40 años, lo cual lo han logrado muy pocos jugadores en la historia de la NBA, consiguiendo a su vez titulos con San Antonio Spurs, premios individuales al mejor sexto hombre en la temporada 2007/2008 y participaciones en el All Stars Game.
# Como conclusiones especificas de los datos trabajados, podemos inferir que su carrera fue evolucionando y mejorando sus estadísticas en sus primeros años desde 2003 hasta 2009/2010 donde llego a tener numeros de una mega estrella, y lo cual se condice en parte con la edad ideal de un deportista de elite (desde los 26 a 30/31 años). Se puede observar que en algunas temporadas donde su participacion en el equipo fue fundamental, los porcentajes de partidos en los que ingreso de titular son bajos pero aun asi la cantidad de minutos disputados fueron creciendo, esto se debe a que para poder participar del premio al mejor sexto hombre, se debe cumplir un % de partidos jugados como suplente y no como titular, ademas de luego ser votado.

# %% [markdown]
# ## 6. Referencias <a id="referencias"></a>
#
# Links
#
# * https://es.wikipedia.org/wiki/Mejor_Sexto_Hombre_de_la_NBA
# * https://www.kaggle.com/nathanlauga/nba-games
