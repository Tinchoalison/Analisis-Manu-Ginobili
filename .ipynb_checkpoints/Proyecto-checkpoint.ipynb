# %%
#Importamos librerias 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.style as sty

# %matplotlib inline

# %%
#Carga y lectura de archivos

path_players = "archivos/players.csv"
arc_players = pd.read_csv(path_players)
path_games_details = "archivos/games_details.csv"
arc_games_details = pd.read_csv(path_games_details)
path_games = "archivos/games.csv"
arc_games = pd.read_csv(path_games)
# Out:
# E:\win10\Alison\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#Copia a archivos para trabajar en duplicado
arc_players_copia = arc_players.copy()
arc_games_details_copia = arc_games_details.copy()
arc_games_copia = arc_games.copy()

# %%
#Hacemos el merge entre los archivos que vamos a usar
merge_games_gamesdetails = arc_games_details_copia.merge(arc_games_copia, on = ['GAME_ID'])

# %%
#Filtramos el dataset de games_details para quedarnos solo con los datos de SAS. Lo guardamos en un nuevo dataset
df_SAS = merge_games_gamesdetails.loc[merge_games_gamesdetails["TEAM_ABBREVIATION"] == "SAS"]

# %%
df_SAS
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 339     22100212  1610612759               SAS  San Antonio    1629640
# 340     22100212  1610612759               SAS  San Antonio     203926
# 341     22100212  1610612759               SAS  San Antonio    1629234
# 342     22100212  1610612759               SAS  San Antonio    1627749
# 343     22100212  1610612759               SAS  San Antonio    1628401
# ...          ...         ...               ...          ...        ...
# 627208  11200024  1610612759               SAS  San Antonio     201986
# 627209  11200024  1610612759               SAS  San Antonio       1536
# 627210  11200024  1610612759               SAS  San Antonio     201168
# 627211  11200024  1610612759               SAS  San Antonio     203174
# 627212  11200024  1610612759               SAS  San Antonio     203178
#
#                PLAYER_NAME  NICKNAME START_POSITION COMMENT    MIN  ...  \
# ...

# %%
#Filtramos el dataset de games_details para quedarnos solo con los datos de Manu Ginobili. Lo guardamos en un nuevo dataset
df_manu = merge_games_gamesdetails.loc[merge_games_gamesdetails["PLAYER_NAME"] == "Manu Ginobili"]

# %%
df_manu
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 69945   20801142  1610612759               SAS  San Antonio       1938
# 70304   20801126  1610612759               SAS  San Antonio       1938
# 70676   20801109  1610612759               SAS  San Antonio       1938
# 71026   20801098  1610612759               SAS  San Antonio       1938
# 71422   20801081  1610612759               SAS  San Antonio       1938
# ...          ...         ...               ...          ...        ...
# 623704  21200047  1610612759               SAS  San Antonio       1938
# 624040  21200035  1610612759               SAS  San Antonio       1938
# 625682  11200085  1610612759               SAS  San Antonio       1938
# 625855  11200082  1610612759               SAS  San Antonio       1938
# 626666  11200044  1610612759               SAS  San Antonio       1938
#
#           PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  AST_home  \
# ...

# %%
#Seleccionamos las columnas que queremos quedarnos del dataset
#union_games_gamesdetails = union_games_gamesdetails[['PLAYER_NAME','SEASON','GAME_ID','PTS','MIN',"START_POSITION"]]
union_games_gamesdetails

# %%
arc_games_merge["SEASON"]

# %%
#Ordenamos el Dataset por temporada
union_games_gamesdetails = union_games_gamesdetails.sort_values(by = ["SEASON"])

# %%
#Reseteamos el indice
union_games_gamesdetails = union_games_gamesdetails.reset_index()

# %%
arc_games_copia = arc_games_copia.sort_values(by = ["SEASON"])

# %%
arc_games_copia = arc_games_copia.reset_index()

# %%
#Completamos los valores nulos de la columna MIN
union_games_gamesdetails[["MIN"]] = union_games_gamesdetails[["MIN"]].fillna(0)
#union_games_gamesdetails["MIN"].unique()

# %%
#Subdividmos la columna MIN debido al formato ", y creamos las columnas minutos y segundos 
union_games_gamesdetails[['minutos','segundos']] = union_games_gamesdetails['MIN'].str.split(':', 1, expand = True)
#union_games_gamesdetails["minutos"].unique()

# %%
#Verificamos si hay valores nulos en mintutos
union_games_gamesdetails.loc[union_games_gamesdetails["minutos"].isnull()]

# %%
# Completamos los valores nulos de minutos y segundos y transformamos las columnas a float
union_games_gamesdetails[["minutos"]] = union_games_gamesdetails[["minutos"]].fillna(0)
union_games_gamesdetails[["segundos"]] = union_games_gamesdetails[["segundos"]].fillna(0)
union_games_gamesdetails[["minutos"]] = union_games_gamesdetails[["minutos"]].astype(float)
union_games_gamesdetails[["segundos"]] = union_games_gamesdetails[["segundos"]].astype(float)

# %%
union_games_gamesdetails.info()

# %%
#Calculamos los puntos por temporada
pts_x_temp = union_games_gamesdetails.groupby("SEASON")["PTS"].sum()

# %%
df["PTS_X_"] = union_games_gamesdetails.groupby("SEASON")["PTS"].sum()
df["PTS_X_"]

# %%
pts_x_temp = pts_x_temp.to_frame().reset_index()

# %%
df["PTS_X_TEMP"] = pts_x_temp[["PTS"]]
df

# %%
#Calculamos los partidos por temporada, usando la columna PTS que solo contiene datos los partidos jugados
partidos_x_temp = union_games_gamesdetails.groupby("SEASON")["PTS"].count()
partidos_x_temp

# %%
#Controlamos que PTS solo tenga datos los partidos en que jugo
union_games_gamesdetails["PTS"].count()

# %%
#Calculamos el promedio de puntos por partido por temporada
promedio_pts_x_temp = union_games_gamesdetails.groupby("SEASON")["PTS"].sum() / union_games_gamesdetails.groupby("SEASON")["PTS"].count()
promedio_pts_x_temp

# %%
#Calculamos los minutos jugados por cada temporada, solo usando la columna minutos
min_x_temp = union_games_gamesdetails.groupby("SEASON")["minutos"].sum()

#Calculamos los segundos jugados por temporada, usando la columna segundos 
segundos_x_temp = union_games_gamesdetails.groupby("SEASON")["segundos"].sum()

#Calculamos los minutos mas los segundos jugados por temporada
minutos_x_temp = union_games_gamesdetails.groupby("SEASON")["minutos"].sum() + (union_games_gamesdetails.groupby("SEASON")["segundos"].sum() / 60)
#min_x_temp
#segundos_x_temp
minutos_x_temp

# %%
#Calculamos los minutos por partido por temporada jugados
promedio_min_x_temp = (union_games_gamesdetails.groupby("SEASON")["minutos"].sum() + (union_games_gamesdetails.groupby("SEASON")["segundos"].sum() / 60)
)  / union_games_gamesdetails.groupby("SEASON")["PTS"].count()
promedio_min_x_temp

# %%
prom_pts_x_min_x_temp = union_games_gamesdetails.groupby("SEASON")["PTS"].sum() / (union_games_gamesdetails.groupby("SEASON")["minutos"].sum() + (union_games_gamesdetails.groupby("SEASON")["segundos"].sum() / 60))
prom_pts_x_min_x_temp

# %%
#Calculamos los partidos jugados de titular
part_titular = union_games_gamesdetails.groupby("SEASON")["START_POSITION"].count()
part_titular

# %%
#Calculamos el porcentaje de partidos jugados de titular
porc_part_titular = (union_games_gamesdetails.groupby("SEASON")["START_POSITION"].count() * 100) / union_games_gamesdetails.groupby("SEASON")["PTS"].count()
porc_part_titular

# %%
union_games_gamesdetails["promedio_reb_x_temp"] = (union_games_gamesdetails.groupby("SEASON")["REB"].sum() / union_games_gamesdetails.groupby("SEASON")["PTS"].count())
promedio_ast_x_temp = union_games_gamesdetails.groupby("SEASON")["AST"].sum() / union_games_gamesdetails.groupby("SEASON")["PTS"].count()
promedio_blk_x_temp = union_games_gamesdetails.groupby("SEASON")["BLK"].sum() / union_games_gamesdetails.groupby("SEASON")["PTS"].count()
promedio_stl_x_temp = union_games_gamesdetails.groupby("SEASON")["STL"].sum() / union_games_gamesdetails.groupby("SEASON")["PTS"].count()
promedio_to_x_temp = union_games_gamesdetails.groupby("SEASON")["TO"].sum() / union_games_gamesdetails.groupby("SEASON")["PTS"].count()

# %%
arc_games_copia  = arc_games_copia.loc[(arc_games_copia ["HOME_TEAM_ID"] == 1610612759) | (arc_games_copia ["VISITOR_TEAM_ID"] == 1610612759)] 
partidos_jugados_SA = arc_games_copia.groupby("SEASON")["GAME_ID"].count()
partidos_jugados_SA
#arc_games_copia

# %%
partidos_ganados_local = arc_games_copia.loc[(arc_games_copia["HOME_TEAM_ID"] == 1610612759) & (arc_games_copia["HOME_TEAM_WINS"] == 1)]
partidos_ganados_local = partidos_ganados_local.groupby("SEASON")["GAME_ID"].count()
partidos_ganados_local

# %%
partidos_ganados_vis = arc_games_copia.loc[(arc_games_copia["VISITOR_TEAM_ID"] == 1610612759) & (arc_games_copia["HOME_TEAM_WINS"] == 0)]
partidos_ganados_vis = partidos_ganados_vis.groupby("SEASON")["GAME_ID"].count()
partidos_ganados_vis

# %%
df = pd.DataFrame()
df["Temporadas"] =  union_games_gamesdetails["SEASON"].unique()
df.reset_index()
df = df.assign(Pts_x_temporada = pts_x_temp)
df
